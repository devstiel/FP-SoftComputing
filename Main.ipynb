# %% [markdown]
# # Optimasi Vehicle Routing Problem <br> Alur Pembuangan Sampah Rayon Surabaya Pusat
# <b> Kelompok 08 </b> <br>
# Nama Anggota :
# 1. Nida Aulia Amartika			(5026221095)
# 2. Isaura Qinthara Heriswan		(5026221146)
# 3. Devy Relliani Saffiyah		(5026221189)

# %% [markdown]
# # Exploratory Data Analysis

# %%
# %pip install scikit-learn
# %pip install folium
# %pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /Users/nida/Library/Python/3.9/lib/python/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /Users/nida/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /Users/nida/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/nida/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/nida/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (3.6.0)
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: folium in /Users/nida/Library/Python/3.9/lib/python/site-packages (0.19.7)
# Requirement already satisfied: branca>=0.6.0 in /Users/nida/Library/Python/3.9/lib/python/site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /Users/nida/Library/Python/3.9/lib/python/site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /Users/nida/Library/Python/3.9/lib/python/site-packages (from folium) (2.0.2)
# Requirement already satisfied: requests in /Users/nida/Library/Python/3.9/lib/python/site-packages (from folium) (2.32.4)
# Requirement already satisfied: xyzservices in /Users/nida/Library/Python/3.9/lib/python/site-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/nida/Library/Python/3.9/lib/python/site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/nida/Library/Python/3.9/lib/python/site-packages (from requests->folium) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nida/Library/Python/3.9/lib/python/site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nida/Library/Python/3.9/lib/python/site-packages (from requests->folium) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nida/Library/Python/3.9/lib/python/site-packages (from requests->folium) (2025.4.26)
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/nida/Library/Python/3.9/lib/python/site-packages (2.3.0)
# Requirement already satisfied: numpy>=1.22.4 in /Users/nida/Library/Python/3.9/lib/python/site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/nida/Library/Python/3.9/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/nida/Library/Python/3.9/lib/python/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/nida/Library/Python/3.9/lib/python/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import random
from sklearn.cluster import KMeans
import folium
import math

# %%
df = pd.read_csv('new_data.csv')
df
# Out:
#     No                      LPS/Depo                                Alamat  \
# 0    1            Demak (Kali Butuh)                           Jalan Demak
# 1    2                      Pringadi                        Jalan Pringadi
# 2    3                      Penghela                        Jalan Penghela
# 3    4                   Sulung Kali                     Jalan Sulung Kali
# 4    5                         Dupak                   Jalan Babatan Dupak
# 5    6                    Simolawang                      Jalan Simolawang
# 6    7                 Pasar Kapasan               Jalan Simolawang Baru I
# 7    8                   Tambak Rejo  Jalan Kenjeran (depan Makam Rangkah)
# 8    9                 Simpang Dukuh                   Jalan Simpang Dukuh
# 9   10                 Pasar Genteng                   Jalan Genteng Besar
# 10  11                         Kayun                           Jalan Kayun
# 11  12               Legundi Anggrek                         Jalan Anggrek
# 12  13                    Pecindilan                 Jalan Raya Pecindilan
# 13  14                 Makam Peneleh                   Jalan Makam Peneleh
# 14  15                     Kedondong                       Jalan Kedondong
# 15  16                  Kedung Anyar                    Jalan Kedung Anyar
# 16  17                 Pasar Kembang              Jalan Wonorejo III Pasar
# 17  18                   Pandegiling                     Jalan Pandegiling
# 18  19                        Dinoyo                          Jalan Dinoyo
# 19  20  Rumah Sakit Darmo / Ketampon                  Jalan Taman Ketampon
# 20  21              Keputran Selatan                Jalan Keputran Selatan
# 21  22                  3R Jambangan           Jalan Jambangan Kebon Agung
# 22  23                    Gayungsari                   Jalan Gayungsari IV
# 23  24                   Nyamplungan                  Jalan KH Mas Mansyur
# 24  25                    Kertopaten                      Jalan Kertopaten
# 25  26                         Jagir                   Jalan Bendul Merisi
# 26  27             Prada Kali Kendal                     Jalan Kali Kendal
# 27  28              Wonokusumo Kidul                 Jalan Wonokusumo Jaya
# 28  29                        Gubeng                Jalan Gubeng Kertajaya
# 29  30                       Sawahan                    Jalan Sawahan Raya
# 30  31                       Kendung                         Jalan Kendung
# 31  32                  Gayung Pring                          Jalan Gayung
# 32  33                      Panghela                        Jalan Panghela
# 33  34                          Giyu                Jalan Rungkut Industri
# 34  35                   Alas Malang                     Jalan Alas Malang
# 35  36                 Babat Jerawat                      Jalan DK Jerawat
# 36  37                       Srikana                         Jalan Srikana
# 37  38                       Keputih                Jalan Raya Marina Asri
# 38  39                  Tambak Deres               Jalan Kyai Tambak Deres
# 39  40                  Pacar Keling                    Jalan Tambang Boyo
# 40  41                        Kaiser                           Jalan Makam
# 41  42                   Medokan Ayu             Jalan Medokan Asri Tengah
# 42  43             Semolowaru Bahari                      Jalan Semolowaru
# 43  44                  Gebang Putih                    Jalan Gebang Putih
# 44  45                       Pesapen                    Jalan Karang Ploso
#
#     Latitude   Longitude  Kapasitas_Sampah(m^3)
# 0  -7.253606  112.720422                      6
# 1  -7.252544  112.733072                      4
# 2  -7.248233  112.733186                      3
# 3  -7.244014  112.742173                      3
# 4  -7.244836  112.727439                      2
# 5  -7.237522  112.753542                      1
# 6  -7.239633  112.750247                      5
# 7  -7.243069  112.760314                      6
# 8  -7.260503  112.742111                      4
# 9  -7.258242  112.740377                      4
# 10 -7.269259  112.747528                      5
# 11 -7.262483  112.752017                      5
# 12 -7.244094  112.747411                      3
# 13 -7.252331  112.741364                      3
# 14 -7.271773  112.738242                      2
# 15 -7.254253  112.731048                      1
# 16 -7.269049  112.729097                      1
# 17 -7.276231  112.735806                      2
# 18 -7.278275  112.743403                      3
# 19 -7.287677  112.736963                      2
# 20 -7.274575  112.743370                      1
# 21 -7.313541  112.732069                      3
# 22 -7.324832  112.749814                      1
# 23 -7.221696  112.750527                      3
# 24 -7.230313  112.741019                      4
# 25 -7.299018  112.753697                      2
# 26 -7.275311  112.695040                      5
# 27 -7.225113  112.752340                      2
# 28 -7.277812  112.761476                      1
# 29 -7.262594  112.728107                      4
# 30 -7.247601  112.635484                      3
# 31 -7.337900  112.728200                      2
# 32 -7.247908  112.733304                      1
# 33 -7.331003  112.771393                      3
# 34 -7.262228  112.643165                      4
# 35 -7.246167  112.629661                      1
# 36 -7.273996  112.758097                      2
# 37 -7.294823  112.807148                      3
# 38 -7.230860  112.785501                      5
# 39 -7.260621  112.758661                      2
# 40 -7.276720  112.713377                      1
# 41 -7.326099  112.795516                      1
# 42 -7.302239  112.788335                      1
# 43 -7.284392  112.785407                      3
# 44 -7.326542  112.674600                      2

# %%
pool = (-7.26053139, 112.692194)   # Pool Tanjungsari
tpa  = (-7.23739100, 112.60943600) # TPA Benowo

# %%
m1 = folium.Map(location=pool, zoom_start=12)
folium.Marker(location=pool, popup='Pool Tanjungsari', icon=folium.Icon(color='red')).add_to(m1)
folium.Marker(location=tpa, popup='TPA Benowo', icon=folium.Icon(color='green')).add_to(m1)
for _, row in df.iterrows():
    folium.Marker(location=(row['Latitude'], row['Longitude']), popup=row['LPS/Depo']).add_to(m1)
m1  # Preview map before VRP
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_09dd8c4ac96da4295be5de0f828716fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_09dd8c4ac96da4295be5de0f828716fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_09dd8c4ac96da4295be5de0f828716fb = L.map(
#                 &quot;map_09dd8c4ac96da4295be5de0f828716fb&quot;,
#                 {
#                     center: [-7.26053139, 112.692194],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d7392d0dc6ec2991f4670afa61b124be = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d7392d0dc6ec2991f4670afa61b124be.addTo(map_09dd8c4ac96da4295be5de0f828716fb);
#
#
#             var marker_52455da6c2f22f8847fd82b267f42ab4 = L.marker(
#                 [-7.26053139, 112.692194],
#                 {
# }
#             ).addTo(map_09dd8c4ac96da4295be5de0f828716fb);
#
#
#             var icon_7eb6b72e1bedf4b404daadde5cde3763 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e9f1803e1ed61513c431ccb6f3f1b078 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87350fe4fe341e3adfec794d067bfcaf = $(`&lt;div id=&quot;html_87350fe4fe341e3adfec794d067bfcaf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pool Tanjungsari&lt;/div&gt;`)[0];
#                 popup_e9f1803e1ed61513c431ccb6f3f1b078.setContent(html_87350fe4fe341e3adfec794d067bfcaf);
#
#
#
#         marker_52455da6c2f22f8847fd82b267f42ab4.bindPopup(popup_e9f1803e1ed61513c431ccb6f3f1b078)
#         ;
#
#
#
#
#                 marker_52455da6c2f22f8847fd82b267f42ab4.setIcon(icon_7eb6b72e1bedf4b404daadde5cde3763);
#
#
#             var marker_0f5356e00b05cfec721ef228221b7df2 = L.marker(
#                 [-7.237391, 112.609436],
#                 {
# }
#             ).addTo(map_09dd8c4ac96da4295be5de0f828716fb);
#
#
#             var icon_493826324a0e4c68d040909e2153ef18 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_462f25079bcf62e9caa8ae9f0728dedf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec679830a14e54417dd89c3f497b9516 = $(`&lt;div id=&quot;html_ec679830a14e54417dd89c3f497b9516&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;TPA Benowo&lt;/div&gt;`)[0];
#                 popup_462f25079bcf62e9caa8ae9f0728dedf.setContent(html_ec679830a14e54417dd89c3f497b9516);
#
#
#
#         marker_0f5356e00b05cfec721ef228221b7df2.bindPopup(popup_462f25079bcf62e9caa8ae9f0728dedf)
#         ;
#
#
#
#
#                 marker_0f5356e00b05cfec721ef228221b7df2.setIcon(icon_493826324a0e4c68d040909e2153ef18);
#
#
#             var marker_7c069d8bedbc64a6c1302dcdf7698151 = L.marker(
#                 [-7.253606, 112.720422],
#                 {
# }
#             ).addTo(map_09dd8c4ac96da4295be5de0f828716fb);
#
#
#         var popup_36a7ce4c3532b64322470bf8f0d9c8a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fcdff5826fe68f405370c42c302b1595 = $(`&lt;div id=&quot;html_fcdff5826fe68f405370c42c302b1595&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Demak (Kali Butuh)&lt;/div&gt;`)[0];
#                 popup_36a7ce4c3532b64322470bf8f0d9c8a7.setContent(html_fcdff5826fe68f405370c42c302b1595);
#
#
#
#         marker_7c069d8bedbc64a6c1302dcdf7698151.bindPopup(popup_36a7ce4c3532b64322470bf8f0d9c8a7)
#         ;
#
#
#
#
#             var marker_d80698f5a8b732f6c602d559ac4f9cfc = L.marker(
#                 [-7.252544, 112.733072],
#                 {
# }
#             ).addTo(map_09dd8c4ac96da4295be5de0f828716fb);
#
#
#         var popup_d6e99b9bd5e88a06da95e68224490cdd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd8725eef6349ddb0dcbc66069970712 = $(`&lt;div id=&quot;html_cd8725eef6349ddb0dcbc66069970712&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;P

# %%
n_vehicles = 11
coords = df[['Latitude','Longitude']].values
kmeans = KMeans(n_clusters=n_vehicles, random_state=42).fit(coords)
df['cluster'] = kmeans.labels_

# %%
colors = ['blue', 'purple', 'orange', 'yellow', 'lightred', 'darkblue', 'darkgreen', 'cadetblue', 'darkpurple', 'pink', 'lightblue']

# Create a new map centered at the pool
m_cluster = folium.Map(location=pool, zoom_start=12)

# Add depot and TPA markers
folium.Marker(location=pool, popup='Pool Tanjungsari', icon=folium.Icon(color='red')).add_to(m_cluster)
folium.Marker(location=tpa, popup='TPA Benowo', icon=folium.Icon(color='green')).add_to(m_cluster)

# Add markers for each point, colored by cluster
for _, row in df.iterrows():
    folium.Marker(location=(row['Latitude'], row['Longitude']),
                  popup=f"{row['LPS/Depo']} (Cluster {row['cluster']})",
                  icon=folium.Icon(color=colors[row['cluster'] % len(colors)])).add_to(m_cluster)

# Display the map
m_cluster
# Out:
# /var/folders/wy/pyy9phgx4kngk0b6dmzdhvdh0000gn/T/ipykernel_39703/1510036970.py:14: UserWarning: color argument of Icon should be one of: {'white', 'darkgreen', 'darkpurple', 'lightred', 'green', 'orange', 'red', 'darkred', 'pink', 'gray', 'lightgreen', 'beige', 'purple', 'lightblue', 'lightgray', 'blue', 'darkblue', 'cadetblue', 'black'}.
#   icon=folium.Icon(color=colors[row['cluster'] % len(colors)])).add_to(m_cluster)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_31507929f68bddbf1d36d09f841aa56f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_31507929f68bddbf1d36d09f841aa56f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_31507929f68bddbf1d36d09f841aa56f = L.map(
#                 &quot;map_31507929f68bddbf1d36d09f841aa56f&quot;,
#                 {
#                     center: [-7.26053139, 112.692194],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9d2cf56e99186df28170f35d609408ee = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9d2cf56e99186df28170f35d609408ee.addTo(map_31507929f68bddbf1d36d09f841aa56f);
#
#
#             var marker_acf1c610b6f20b1070caf9da490f9f1c = L.marker(
#                 [-7.26053139, 112.692194],
#                 {
# }
#             ).addTo(map_31507929f68bddbf1d36d09f841aa56f);
#
#
#             var icon_0f12bcad65ec734c2fb081d86d50d069 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a4da65fae6246ae1461efffc618f6126 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9d705b342469933dc7a759e432bb532e = $(`&lt;div id=&quot;html_9d705b342469933dc7a759e432bb532e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pool Tanjungsari&lt;/div&gt;`)[0];
#                 popup_a4da65fae6246ae1461efffc618f6126.setContent(html_9d705b342469933dc7a759e432bb532e);
#
#
#
#         marker_acf1c610b6f20b1070caf9da490f9f1c.bindPopup(popup_a4da65fae6246ae1461efffc618f6126)
#         ;
#
#
#
#
#                 marker_acf1c610b6f20b1070caf9da490f9f1c.setIcon(icon_0f12bcad65ec734c2fb081d86d50d069);
#
#
#             var marker_e1dd28c8dc0875294f2bc8c0cb557431 = L.marker(
#                 [-7.237391, 112.609436],
#                 {
# }
#             ).addTo(map_31507929f68bddbf1d36d09f841aa56f);
#
#
#             var icon_ae9c32974a5ac31ba0e89186553cf4a3 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_56b9426ec24e545b7259473f6a07b233 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3b6931dc870dd4099840550b101a30b = $(`&lt;div id=&quot;html_e3b6931dc870dd4099840550b101a30b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;TPA Benowo&lt;/div&gt;`)[0];
#                 popup_56b9426ec24e545b7259473f6a07b233.setContent(html_e3b6931dc870dd4099840550b101a30b);
#
#
#
#         marker_e1dd28c8dc0875294f2bc8c0cb557431.bindPopup(popup_56b9426ec24e545b7259473f6a07b233)
#         ;
#
#
#
#
#                 marker_e1dd28c8dc0875294f2bc8c0cb557431.setIcon(icon_ae9c32974a5ac31ba0e89186553cf4a3);
#
#
#             var marker_b276ffb828f735a042d65179e430c395 = L.marker(
#                 [-7.253606, 112.720422],
#                 {
# }
#             ).addTo(map_31507929f68bddbf1d36d09f841aa56f);
#
#
#             var icon_b97db0779f358c2d77360c9281170cac = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkpurple&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_1ad603d8ca7b588400c7c41ee5631f8c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9fd531e9119bbddcbe5aa1f3b57d53b = $(`&lt;div id=&quot;html_f9fd531e9119bbddcbe5aa1f3b57d53b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Demak (Kali Butuh) (Cluster 8)&lt;/div&gt;`)[0];
#                 popup_1ad603d8ca7b588400c7c41ee5631f8c.setContent(html_f9fd531e9119bbddcbe5aa1f3b57d53b);
#
#
#
#         marker_b276ffb828f735a042d65179e430c395.bindPopup(popup_1ad603d8ca7b588400c7c41ee5631f8c)
#         ;
#
#
#
#
#                 marker_b276ffb828f735a042d65179e430c395.setIcon(icon_b97db0779f358c2d77360c9281170cac);
#
#
#             v

# %%
def haversine(a, b):
    R = 6371e3
    φ1, φ2 = math.radians(a[0]), math.radians(b[0])
    Δφ = math.radians(b[0] - a[0])
    Δλ = math.radians(b[1] - a[1])
    x = math.sin(Δφ/2)**2 + math.cos(φ1)*math.cos(φ2)*math.sin(Δλ/2)**2
    return R * 2 * math.asin(math.sqrt(x))

# %%
def route_distance(route):
    dist = 0
    prev = pool
    for pt in route:
        dist += haversine(prev, pt)
        prev = pt
    dist += haversine(prev, tpa) + haversine(tpa, pool)
    return dist

# %%
def order_crossover(p1, p2):
    size = len(p1)
    a, b = sorted(random.sample(range(size), 2))
    c1 = [None]*size
    c2 = [None]*size
    c1[a:b], c2[a:b] = p1[a:b], p2[a:b]
    def fill(child, parent):
        pos = b
        for gene in parent[b:] + parent[:b]:
            if gene not in child:
                if pos >= size: pos = 0
                child[pos] = gene
                pos += 1
    fill(c1, p2)
    fill(c2, p1)
    return c1, c2

# %%
def mutate(ind):
    if len(ind) > 1:
        i, j = random.sample(range(len(ind)), 2)
        ind[i], ind[j] = ind[j], ind[i]

# %%
def ga_cluster(points, pop_size=150, gens=800, elite_size=1):
    n = len(points)
    if n < 2:
        return points

    # initialize population
    population = [random.sample(range(n), n) for _ in range(pop_size)]

    for _ in range(gens):
        # compute fitness for roulette selection
        fitness = [1/(route_distance([points[i] for i in ind]) + 1) for ind in population]
        total = sum(fitness)
        probs = [f/total for f in fitness]

        # select elites (best individuals) to carry forward
        sorted_pop = sorted(
            population,
            key=lambda ind: route_distance([points[i] for i in ind])
        )
        new_pop = [sorted_pop[i].copy() for i in range(elite_size)]

        # fill the rest of new_pop by crossover + mutation
        while len(new_pop) < pop_size:
            # select two parents
            p1, p2 = random.choices(population, probs, k=2)
            # crossover
            if random.random() < 0.8:
                c1, c2 = order_crossover(p1, p2)
            else:
                c1, c2 = p1[:], p2[:]
            # mutate
            if random.random() < 0.2:
                mutate(c1)
            if random.random() < 0.2:
                mutate(c2)

            new_pop.append(c1)
            if len(new_pop) < pop_size:
                new_pop.append(c2)

        population = new_pop

    # return the best route as actual coordinates
    best = min(
        population,
        key=lambda ind: route_distance([points[i] for i in ind])
    )
    return [points[i] for i in best]

# %%
m2 = folium.Map(location=pool, zoom_start=12)
folium.Marker(location=pool, popup='Pool Tanjungsari', icon=folium.Icon(color='red')).add_to(m2)
folium.Marker(location=tpa, popup='TPA Benowo', icon=folium.Icon(color='green')).add_to(m2)

# Colors already defined above - no need to redefine

coord_to_name = {
    (row['Latitude'], row['Longitude']): row['LPS/Depo']
    for _, row in df.iterrows()
}
coord_to_name[pool] = "Pool Tanjungsari"
coord_to_name[tpa]  = "TPA Benowo"

for vid in range(n_vehicles):
    # get the raw coordinates in this cluster
    cluster_pts = coords[kmeans.labels_ == vid]
    if len(cluster_pts) == 0:
        continue

    # GA wants a Python list of tuple‐points
    pts_list = [tuple(pt) for pt in cluster_pts]

    # find best ordering of stops
    best_route = ga_cluster(pts_list)

    # build the full trip for plotting
    full_route = [pool] + best_route + [tpa, pool]

    # 1) draw it on the map
    folium.PolyLine(
        locations=full_route,
        color=colors[vid % len(colors)],
        weight=2.5, opacity=0.8,
        popup=f'Vehicle {vid+1}'
    ).add_to(m2)

    # 2) compute the true total distance via route_distance(best_route)
    #    (it already adds pool→stops→TPA→pool)
    total_dist_km = route_distance(best_route) / 1000

    # 3) map coords back to names
    path_names = [coord_to_name[c] for c in full_route]
    print(f"Vehicle {vid+1}: " + " → ".join(path_names))
    print(f"  Total distance: {total_dist_km:.2f} km\n")

# finally show the map
m2
# Out:
# Vehicle 1: Pool Tanjungsari → Pasar Kembang → Pandegiling → Kedondong → Keputran Selatan → Dinoyo → Rumah Sakit Darmo / Ketampon → TPA Benowo → Pool Tanjungsari
#   Total distance: 32.77 km
#
# Vehicle 2: Pool Tanjungsari → Giyu → Gayungsari → TPA Benowo → Pool Tanjungsari
#   Total distance: 41.98 km
#
# Vehicle 3: Pool Tanjungsari → Alas Malang → Kendung → Babat Jerawat → TPA Benowo → Pool Tanjungsari
#   Total distance: 19.83 km
#
# Vehicle 4: Pool Tanjungsari → Kayun → Srikana → Gubeng → Pacar Keling → Legundi Anggrek → TPA Benowo → Pool Tanjungsari
#   Total distance: 36.18 km
#
# Vehicle 5: Pool Tanjungsari → Jagir → 3R Jambangan → Gayung Pring → TPA Benowo → Pool Tanjungsari
#   Total distance: 40.35 km
#
# Vehicle 6: Pool Tanjungsari → Gebang Putih → Keputih → Medokan Ayu → Semolowaru Bahari → TPA Benowo → Pool Tanjungsari
#   Total distance: 50.25 km
#
# Vehicle 7: Pool Tanjungsari → Sulung Kali → Pecindilan → Pasar Kapasan → Tambak Rejo → Simolawang → Wonokusumo Kidul → Nyamplungan → Kertopaten → TPA Benowo → Pool Tanjungsari
#   Total distance: 36.38 km
#
# Vehicle 8: Pool Tanjungsari → Tambak Deres → TPA Benowo → Pool Tanjungsari
#   Total distance: 39.73 km
#
# Vehicle 9: Pool Tanjungsari → Sawahan → Simpang Dukuh → Pasar Genteng → Makam Peneleh → Pringadi → Kedung Anyar → Penghela → Panghela → Dupak → Demak (Kali Butuh) → TPA Benowo → Pool Tanjungsari
#   Total distance: 32.30 km
#
# Vehicle 10: Pool Tanjungsari → Pesapen → TPA Benowo → Pool Tanjungsari
#   Total distance: 29.32 km
#
# Vehicle 11: Pool Tanjungsari → Kaiser → Prada Kali Kendal → TPA Benowo → Pool Tanjungsari
#   Total distance: 24.80 km
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a7608116f22e85934465c61a140dddde {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a7608116f22e85934465c61a140dddde&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a7608116f22e85934465c61a140dddde = L.map(
#                 &quot;map_a7608116f22e85934465c61a140dddde&quot;,
#                 {
#                     center: [-7.26053139, 112.692194],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f83a82adb1833d5d4a1cb366d30b58f4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f83a82adb1833d5d4a1cb366d30b58f4.addTo(map_a7608116f22e85934465c61a140dddde);
#
#
#             var marker_8fe24fa403a05f591b4e1d61f1985787 = L.marker(
#                 [-7.26053139, 112.692194],
#                 {
# }
#             ).addTo(map_a7608116f22e85934465c61a140dddde);
#
#
#             var icon_1febe056a7b63d395ec8cc1883402f3f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8157d78692d7f9f6e277b3403c225ec1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_469d0a35b795f20f28c705ac4c3638dc = $(`&lt;div id=&quot;html_469d0a35b795f20f28c705ac4c3638dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pool Tanjungsari&lt;/div&gt;`)[0];
#                 popup_8157d78692d7f9f6e277b3403c225ec1.setContent(html_469d0a35b795f20f28c705ac4c3638dc);
#
#
#
#         marker_8fe24fa403a05f591b4e1d61f1985787.bindPopup(popup_8157d78692d7f9f6e277b3403c225ec1)
#         ;
#
#
#
#
#                 marker_8fe24fa403a05f591b4e1d61f1985787.setIcon(icon_1febe056a7b63d395ec8cc1883402f3f);
#
#
#             var marker_7f38592f125bee7025aef48e5c11a9cb = L.marker(
#                 [-7.237391, 112.609436],
#                 {
# }
#             ).addTo(map_a7608116f22e85934465c61a140dddde);
#
#
#             var icon_c39f6191a173413bb0d248b0ca635818 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_7b0fbefa087e7adf42801d449234fd8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_055bb29394a870dd589b22c100b8c38a = $(`&lt;div id=&quot;html_055bb29394a870dd589b22c100b8c38a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;TPA Benowo&lt;/div&gt;`)[0];
#                 popup_7b0fbefa087e7adf42801d449234fd8e.setContent(html_055bb29394a870dd589b22c100b8c38a);
#
#
#
#         marker_7f38592f125bee7025aef48e5c11a9cb.bindPopup(popup_7b0fbefa087e7adf42801d449234fd8e)
#         ;
#
#
#
#
#                 marker_7f38592f125bee7025aef48e5c11a9cb.setIcon(icon_c39f6191a173413bb0d248b0ca635818);
#
#
#             var poly_line_39fc54dc69a20941d82ba519602b27a7 = L.polyline(
#                 [[-7.26053139, 112.692194], [-7.269049, 112.729097], [-7.276231, 112.735806], [-7.271773, 112.738242], [-7.274575, 112.74337], [-7.278275, 112.743403], [-7.287677, 112.736963], [-7.237391, 112.609436], [-7.26053139, 112.692194]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_a7608116f22e85934465c61a140dddde);
#
#
#         var popup_d033e8b4fff1bee7f76f51d6226c5224 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76c3a4a04731bd03c2225122ff99497c = $(`&lt;div id=&quot;html_76c3a4a04731bd03c2225122ff99497c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vehicle 1&lt;/div&gt;`)[0];
#                 popup_d033e8b4fff1bee7f76f51d6226c5224.setContent(html_76c3a4a04

# %%
colors = ['blue', 'purple', 'orange', 'yellow', 'lightred', 'darkblue', 'darkgreen', 'cadetblue', 'darkpurple', 'pink', 'lightblue']

coord_to_name = {
    (row['Latitude'], row['Longitude']): row['LPS/Depo']
    for _, row in df.iterrows()
}
coord_to_name[pool] = "Pool Tanjungsari"
coord_to_name[tpa]  = "TPA Benowo"

for vid in range(n_vehicles):
    # get the raw coordinates in this cluster
    cluster_pts = coords[kmeans.labels_ == vid]
    if len(cluster_pts) == 0:
        continue

    # GA wants a Python list of tuple‐points
    pts_list = [tuple(pt) for pt in cluster_pts]

    # find best ordering of stops
    best_route = ga_cluster(pts_list)

    # build the full trip for plotting
    full_route = [pool] + best_route + [tpa, pool]

    # 1) draw it on the map
    folium.PolyLine(
        locations=full_route,
        color=colors[vid % len(colors)],
        weight=2.5, opacity=0.8,
        popup=f'Vehicle {vid+1}'
    ).add_to(m2)

    # 2) compute the true total distance via route_distance(best_route)
    #    (it already adds pool→stops→TPA→pool)
    total_dist_km = route_distance(best_route) / 1000

    # 3) map coords back to names
    path_names = [coord_to_name[c] for c in full_route]
    print(f"Vehicle {vid+1}: " + " → ".join(path_names))
    print(f"  Total distance: {total_dist_km:.2f} km\n")

# finally show the map
m2
# Out:
# Vehicle 1: Pool Tanjungsari → Pasar Kembang → Pandegiling → Kedondong → Keputran Selatan → Dinoyo → Rumah Sakit Darmo / Ketampon → TPA Benowo → Pool Tanjungsari
#   Total distance: 32.77 km
#
# Vehicle 2: Pool Tanjungsari → Giyu → Gayungsari → TPA Benowo → Pool Tanjungsari
#   Total distance: 41.98 km
#
# Vehicle 3: Pool Tanjungsari → Alas Malang → Kendung → Babat Jerawat → TPA Benowo → Pool Tanjungsari
#   Total distance: 19.83 km
#
# Vehicle 4: Pool Tanjungsari → Kayun → Srikana → Gubeng → Pacar Keling → Legundi Anggrek → TPA Benowo → Pool Tanjungsari
#   Total distance: 36.18 km
#
# Vehicle 5: Pool Tanjungsari → Jagir → 3R Jambangan → Gayung Pring → TPA Benowo → Pool Tanjungsari
#   Total distance: 40.35 km
#
# Vehicle 6: Pool Tanjungsari → Gebang Putih → Keputih → Medokan Ayu → Semolowaru Bahari → TPA Benowo → Pool Tanjungsari
#   Total distance: 50.25 km
#
# Vehicle 7: Pool Tanjungsari → Sulung Kali → Pecindilan → Pasar Kapasan → Tambak Rejo → Simolawang → Wonokusumo Kidul → Nyamplungan → Kertopaten → TPA Benowo → Pool Tanjungsari
#   Total distance: 36.38 km
#
# Vehicle 8: Pool Tanjungsari → Tambak Deres → TPA Benowo → Pool Tanjungsari
#   Total distance: 39.73 km
#
# Vehicle 9: Pool Tanjungsari → Sawahan → Kedung Anyar → Pringadi → Pasar Genteng → Simpang Dukuh → Makam Peneleh → Penghela → Panghela → Dupak → Demak (Kali Butuh) → TPA Benowo → Pool Tanjungsari
#   Total distance: 32.38 km
#
# Vehicle 10: Pool Tanjungsari → Pesapen → TPA Benowo → Pool Tanjungsari
#   Total distance: 29.32 km
#
# Vehicle 11: Pool Tanjungsari → Kaiser → Prada Kali Kendal → TPA Benowo → Pool Tanjungsari
#   Total distance: 24.80 km
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a7608116f22e85934465c61a140dddde {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a7608116f22e85934465c61a140dddde&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a7608116f22e85934465c61a140dddde = L.map(
#                 &quot;map_a7608116f22e85934465c61a140dddde&quot;,
#                 {
#                     center: [-7.26053139, 112.692194],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f83a82adb1833d5d4a1cb366d30b58f4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f83a82adb1833d5d4a1cb366d30b58f4.addTo(map_a7608116f22e85934465c61a140dddde);
#
#
#             var marker_8fe24fa403a05f591b4e1d61f1985787 = L.marker(
#                 [-7.26053139, 112.692194],
#                 {
# }
#             ).addTo(map_a7608116f22e85934465c61a140dddde);
#
#
#             var icon_1febe056a7b63d395ec8cc1883402f3f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8157d78692d7f9f6e277b3403c225ec1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_469d0a35b795f20f28c705ac4c3638dc = $(`&lt;div id=&quot;html_469d0a35b795f20f28c705ac4c3638dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pool Tanjungsari&lt;/div&gt;`)[0];
#                 popup_8157d78692d7f9f6e277b3403c225ec1.setContent(html_469d0a35b795f20f28c705ac4c3638dc);
#
#
#
#         marker_8fe24fa403a05f591b4e1d61f1985787.bindPopup(popup_8157d78692d7f9f6e277b3403c225ec1)
#         ;
#
#
#
#
#                 marker_8fe24fa403a05f591b4e1d61f1985787.setIcon(icon_1febe056a7b63d395ec8cc1883402f3f);
#
#
#             var marker_7f38592f125bee7025aef48e5c11a9cb = L.marker(
#                 [-7.237391, 112.609436],
#                 {
# }
#             ).addTo(map_a7608116f22e85934465c61a140dddde);
#
#
#             var icon_c39f6191a173413bb0d248b0ca635818 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_7b0fbefa087e7adf42801d449234fd8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_055bb29394a870dd589b22c100b8c38a = $(`&lt;div id=&quot;html_055bb29394a870dd589b22c100b8c38a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;TPA Benowo&lt;/div&gt;`)[0];
#                 popup_7b0fbefa087e7adf42801d449234fd8e.setContent(html_055bb29394a870dd589b22c100b8c38a);
#
#
#
#         marker_7f38592f125bee7025aef48e5c11a9cb.bindPopup(popup_7b0fbefa087e7adf42801d449234fd8e)
#         ;
#
#
#
#
#                 marker_7f38592f125bee7025aef48e5c11a9cb.setIcon(icon_c39f6191a173413bb0d248b0ca635818);
#
#
#             var poly_line_39fc54dc69a20941d82ba519602b27a7 = L.polyline(
#                 [[-7.26053139, 112.692194], [-7.269049, 112.729097], [-7.276231, 112.735806], [-7.271773, 112.738242], [-7.274575, 112.74337], [-7.278275, 112.743403], [-7.287677, 112.736963], [-7.237391, 112.609436], [-7.26053139, 112.692194]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_a7608116f22e85934465c61a140dddde);
#
#
#         var popup_d033e8b4fff1bee7f76f51d6226c5224 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76c3a4a04731bd03c2225122ff99497c = $(`&lt;div id=&quot;html_76c3a4a04731bd03c2225122ff99497c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vehicle 1&lt;/div&gt;`)[0];
#                 popup_d033e8b4fff1bee7f76f51d6226c5224.setContent(html_76c3a4a04

# %% [markdown]
# # VRP WITH ANT COLONY OPTIMIZATION

# %%
# Load kapasitas truk
df_truk = pd.read_csv('kapasitas-truk.csv', sep = ';')
df_truk
# Out:
#    No Jenis Kendaraan  Volume (m^3)
# 0   1      Truk Kecil             7
# 1   2    Truk 3.5 Ton            12
# 2   3  Arm Roll Truck            18

# %%
# Fungsi Ant Colony Optimization sederhana
def ant_colony_tsp(points, n_ants=70, n_iterations=300, alpha=1, beta=2, evaporation=0.4):
    n = len(points)
    dist_matrix = np.zeros((n, n))
    for i in range(n):
        for j in range(n):
            if i != j:
                dist_matrix[i][j] = haversine(points[i], points[j])
            else:
                dist_matrix[i][j] = 1e-6  # avoid divide by zero

    pheromone = np.ones((n, n))
    best_distance = float('inf')
    best_path = []

    for _ in range(n_iterations):
        all_paths = []
        all_lengths = []

        for _ in range(n_ants):
            unvisited = list(range(n))
            start = random.choice(unvisited)
            path = [start]
            unvisited.remove(start)

            while unvisited:
                curr = path[-1]
                probs = []
                for j in unvisited:
                    tau = pheromone[curr][j] ** alpha
                    eta = (1 / dist_matrix[curr][j]) ** beta
                    probs.append(tau * eta)
                probs = np.array(probs)
                probs /= probs.sum()
                next_node = np.random.choice(unvisited, p=probs)
                path.append(next_node)
                unvisited.remove(next_node)

            length = sum(dist_matrix[path[i]][path[i + 1]] for i in range(n - 1))
            length += haversine(pool, points[path[0]])  # pool to start
            length += haversine(points[path[-1]], tpa)  # end to TPA
            length += haversine(tpa, pool)             # TPA to pool

            all_paths.append(path)
            all_lengths.append(length)

        shortest_idx = np.argmin(all_lengths)
        if all_lengths[shortest_idx] < best_distance:
            best_distance = all_lengths[shortest_idx]
            best_path = all_paths[shortest_idx]

        # Update pheromone
        pheromone *= (1 - evaporation)
        for path, length in zip(all_paths, all_lengths):
            for i in range(n - 1):
                pheromone[path[i]][path[i + 1]] += 1 / length

    return [points[i] for i in best_path], best_distance

# %%
# Map baru ACO
m3 = folium.Map(location=pool, zoom_start=12)
total_distance_aco = 0
# Add depot and TPA markers
folium.Marker(location=pool, popup='Pool Tanjungsari', icon=folium.Icon(color='red')).add_to(m3)
folium.Marker(location=tpa, popup='TPA Benowo', icon=folium.Icon(color='green')).add_to(m3)

# Map koordinat ke kapasitas
coord_to_capacity = {
    (row['Latitude'], row['Longitude']): row['Kapasitas_Sampah(m^3)']
    for _, row in df.iterrows()
}

for vid in range(n_vehicles):
    cluster_pts = coords[kmeans.labels_ == vid]
    if len(cluster_pts) == 0:
        continue

    pts_list = [tuple(pt) for pt in cluster_pts]
    capacities = [coord_to_capacity[pt] for pt in pts_list]
    total_volume = sum(capacities)

    # Pilih truk terkecil yang muat
    truk_terpilih = None
    for _, row in df_truk.iterrows():
        if total_volume <= row['Volume (m^3)']:
            truk_terpilih = row
            break
    if truk_terpilih is None:
        truk_terpilih = df_truk.iloc[-1]  # Gunakan terbesar jika semuanya tidak cukup

    # ACO untuk rute terbaik
    best_path, best_dist = ant_colony_tsp(pts_list)
    total_distance_aco += best_dist

    # Bangun rute lengkap
    full_route = [pool] + best_path + [tpa, pool]
    color = colors[vid % len(colors)]
    folium.PolyLine(locations=full_route, color=color, weight=2.5,
                    opacity=0.8, popup=f'Vehicle {vid+1}').add_to(m3)

    path_names = [coord_to_name.get(c, 'Unknown') for c in full_route]


    print(f"[ACO] Vehicle {vid+1}: " + " → ".join(path_names))
    print(f"  Total distance: {best_dist/1000:.2f} km")
    print(f"  Total volume sampah: {total_volume:.1f} m^3")
    print(f"  Jenis truk yang digunakan: {truk_terpilih['Jenis Kendaraan']} (kapasitas {truk_terpilih['Volume (m^3)']} m^3)\n")

print(f"TOTAL DISTANCE ALL VEHICLES [ACO]: {total_distance_aco / 1000:.2f} km")
# Tampilkan map
m3
# Out:
# [ACO] Vehicle 1: Pool Tanjungsari → Pasar Kembang → Pandegiling → Kedondong → Keputran Selatan → Dinoyo → Rumah Sakit Darmo / Ketampon → TPA Benowo → Pool Tanjungsari
#   Total distance: 32.77 km
#   Total volume sampah: 11.0 m^3
#   Jenis truk yang digunakan: Truk 3.5 Ton (kapasitas 12 m^3)
#
# [ACO] Vehicle 2: Pool Tanjungsari → Giyu → Gayungsari → TPA Benowo → Pool Tanjungsari
#   Total distance: 41.98 km
#   Total volume sampah: 4.0 m^3
#   Jenis truk yang digunakan: Truk Kecil (kapasitas 7 m^3)
#
# [ACO] Vehicle 3: Pool Tanjungsari → Alas Malang → Kendung → Babat Jerawat → TPA Benowo → Pool Tanjungsari
#   Total distance: 19.83 km
#   Total volume sampah: 8.0 m^3
#   Jenis truk yang digunakan: Truk 3.5 Ton (kapasitas 12 m^3)
#
# [ACO] Vehicle 4: Pool Tanjungsari → Kayun → Srikana → Gubeng → Pacar Keling → Legundi Anggrek → TPA Benowo → Pool Tanjungsari
#   Total distance: 36.18 km
#   Total volume sampah: 15.0 m^3
#   Jenis truk yang digunakan: Arm Roll Truck (kapasitas 18 m^3)
#
# [ACO] Vehicle 5: Pool Tanjungsari → Jagir → 3R Jambangan → Gayung Pring → TPA Benowo → Pool Tanjungsari
#   Total distance: 40.35 km
#   Total volume sampah: 7.0 m^3
#   Jenis truk yang digunakan: Truk Kecil (kapasitas 7 m^3)
#
# [ACO] Vehicle 6: Pool Tanjungsari → Gebang Putih → Keputih → Medokan Ayu → Semolowaru Bahari → TPA Benowo → Pool Tanjungsari
#   Total distance: 50.25 km
#   Total volume sampah: 8.0 m^3
#   Jenis truk yang digunakan: Truk 3.5 Ton (kapasitas 12 m^3)
#
# [ACO] Vehicle 7: Pool Tanjungsari → Sulung Kali → Pecindilan → Pasar Kapasan → Tambak Rejo → Simolawang → Wonokusumo Kidul → Nyamplungan → Kertopaten → TPA Benowo → Pool Tanjungsari
#   Total distance: 36.38 km
#   Total volume sampah: 27.0 m^3
#   Jenis truk yang digunakan: Arm Roll Truck (kapasitas 18 m^3)
#
# [ACO] Vehicle 8: Pool Tanjungsari → Tambak Deres → TPA Benowo → Pool Tanjungsari
#   Total distance: 39.73 km
#   Total volume sampah: 5.0 m^3
#   Jenis truk yang digunakan: Truk Kecil (kapasitas 7 m^3)
#
# [ACO] Vehicle 9: Pool Tanjungsari → Demak (Kali Butuh) → Sawahan → Simpang Dukuh → Pasar Genteng → Makam Peneleh → Kedung Anyar → Pringadi → Penghela → Panghela → Dupak → TPA Benowo → Pool Tanjungsari
#   Total distance: 32.29 km
#   Total volume sampah: 32.0 m^3
#   Jenis truk yang digunakan: Arm Roll Truck (kapasitas 18 m^3)
#
# [ACO] Vehicle 10: Pool Tanjungsari → Pesapen → TPA Benowo → Pool Tanjungsari
#   Total distance: 29.32 km
#   Total volume sampah: 2.0 m^3
#   Jenis truk yang digunakan: Truk Kecil (kapasitas 7 m^3)
#
# [ACO] Vehicle 11: Pool Tanjungsari → Kaiser → Prada Kali Kendal → TPA Benowo → Pool Tanjungsari
#   Total distance: 24.80 km
#   Total volume sampah: 6.0 m^3
#   Jenis truk yang digunakan: Truk Kecil (kapasitas 7 m^3)
#
# TOTAL DISTANCE ALL VEHICLES [ACO]: 383.88 km
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d181e5df7a0d57154d11b0c178bc3f96 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d181e5df7a0d57154d11b0c178bc3f96&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d181e5df7a0d57154d11b0c178bc3f96 = L.map(
#                 &quot;map_d181e5df7a0d57154d11b0c178bc3f96&quot;,
#                 {
#                     center: [-7.26053139, 112.692194],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_48bcfefb5a5510e105076a1afbe6a77c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_48bcfefb5a5510e105076a1afbe6a77c.addTo(map_d181e5df7a0d57154d11b0c178bc3f96);
#
#
#             var marker_b59885e8884f93fa1fcffa4df7c274df = L.marker(
#                 [-7.26053139, 112.692194],
#                 {
# }
#             ).addTo(map_d181e5df7a0d57154d11b0c178bc3f96);
#
#
#             var icon_fba7c445876e1011037c4beb1cb8db3b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_40b49baafc6cf97ec63ff5f09775ac22 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ab98955e2be80d619240f439c88995b = $(`&lt;div id=&quot;html_9ab98955e2be80d619240f439c88995b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pool Tanjungsari&lt;/div&gt;`)[0];
#                 popup_40b49baafc6cf97ec63ff5f09775ac22.setContent(html_9ab98955e2be80d619240f439c88995b);
#
#
#
#         marker_b59885e8884f93fa1fcffa4df7c274df.bindPopup(popup_40b49baafc6cf97ec63ff5f09775ac22)
#         ;
#
#
#
#
#                 marker_b59885e8884f93fa1fcffa4df7c274df.setIcon(icon_fba7c445876e1011037c4beb1cb8db3b);
#
#
#             var marker_8e2dd5db883ebbcda86b1745acf4a2d5 = L.marker(
#                 [-7.237391, 112.609436],
#                 {
# }
#             ).addTo(map_d181e5df7a0d57154d11b0c178bc3f96);
#
#
#             var icon_a6036a2489753ee4f9dbf74933c17fb6 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_f02201ff361c212fd71c83092a8006d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f67ae35326dd61c2a980d3f44ec6561 = $(`&lt;div id=&quot;html_2f67ae35326dd61c2a980d3f44ec6561&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;TPA Benowo&lt;/div&gt;`)[0];
#                 popup_f02201ff361c212fd71c83092a8006d7.setContent(html_2f67ae35326dd61c2a980d3f44ec6561);
#
#
#
#         marker_8e2dd5db883ebbcda86b1745acf4a2d5.bindPopup(popup_f02201ff361c212fd71c83092a8006d7)
#         ;
#
#
#
#
#                 marker_8e2dd5db883ebbcda86b1745acf4a2d5.setIcon(icon_a6036a2489753ee4f9dbf74933c17fb6);
#
#
#             var poly_line_bc139fed294b31d1643659bb0085cc7e = L.polyline(
#                 [[-7.26053139, 112.692194], [-7.269049, 112.729097], [-7.276231, 112.735806], [-7.271773, 112.738242], [-7.274575, 112.74337], [-7.278275, 112.743403], [-7.287677, 112.736963], [-7.237391, 112.609436], [-7.26053139, 112.692194]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_d181e5df7a0d57154d11b0c178bc3f96);
#
#
#         var popup_e0d8aba9670a192bbe4e5574c4993058 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a22dedb66c0c5f58fc5f6993b93f3af5 = $(`&lt;div id=&quot;html_a22dedb66c0c5f58fc5f6993b93f3af5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vehicle 1&lt;/div&gt;`)[0];
#                 popup_e0d8aba9670a192bbe4e5574c4993058.setContent(html_a22dedb66

# %% [markdown]
# # VRP WITH TABU SEARCH ALGORITHM

# %%
class TabuSearch:
    def __init__(self, points, capacities, max_vehicle_capacity, tabu_tenure=10, max_iterations=100):
        self.points = points
        self.capacities = capacities
        self.max_capacity = max_vehicle_capacity
        self.tabu_tenure = tabu_tenure
        self.max_iterations = max_iterations
        self.tabu_list = []
        self.best_solution = None
        self.best_distance = float('inf')
        
    def calculate_route_distance(self, route):
        """Calculate total distance for a route including pool->stops->TPA->pool"""
        if not route:
            return 0
        
        dist = haversine(pool, self.points[route[0]])  # pool to first stop
        for i in range(len(route) - 1):
            dist += haversine(self.points[route[i]], self.points[route[i+1]])
        dist += haversine(self.points[route[-1]], tpa)  # last stop to TPA
        dist += haversine(tpa, pool)  # TPA back to pool
        return dist
    
    def generate_initial_solution(self):
        """Generate initial single-route solution visiting all points""" 
        return [list(range(len(self.points)))]  # wrap in list as solution with 1 route

    def get_neighbors(self, solution):
        """Generate neighbors with 2-opt moves within the single route only"""
        neighbors = []
        route = solution[0]  # single route
        
        for i in range(len(route) - 1):
            for j in range(i + 2, len(route)):
                new_route = route[:i+1] + route[i+1:j+1][::-1] + route[j+1:]
                neighbors.append([new_route])  # wrap in list as solution with 1 route
        
        return neighbors
        
    def solution_distance(self, solution):
        """Calculate total distance for entire solution"""
        return sum(self.calculate_route_distance(route) for route in solution)
    
    def is_tabu(self, move):
        """Check if move is in tabu list"""
        return move in self.tabu_list
    
    def add_to_tabu(self, move):
        """Add move to tabu list with tenure management"""
        self.tabu_list.append(move)
        if len(self.tabu_list) > self.tabu_tenure:
            self.tabu_list.pop(0)
    
    def solve(self):
        """Main tabu search algorithm"""
        current_solution = self.generate_initial_solution()
        current_distance = self.solution_distance(current_solution)
        
        self.best_solution = [r[:] for r in current_solution]
        self.best_distance = current_distance
        
        for iteration in range(self.max_iterations):
            neighbors = self.get_neighbors(current_solution)
            
            if not neighbors:
                break
            
            best_neighbor = None
            best_neighbor_distance = float('inf')
            best_move = None
            
            for neighbor in neighbors:
                neighbor_distance = self.solution_distance(neighbor)
                move = str(neighbor)  # Simple move representation
                
                if (neighbor_distance < best_neighbor_distance and 
                    (not self.is_tabu(move) or neighbor_distance < self.best_distance)):
                    best_neighbor = neighbor
                    best_neighbor_distance = neighbor_distance
                    best_move = move
            
            if best_neighbor is None:
                break
            
            current_solution = best_neighbor
            current_distance = best_neighbor_distance
            
            if best_move:
                self.add_to_tabu(best_move)
            
            if current_distance < self.best_distance:
                self.best_solution = [r[:] for r in current_solution]
                self.best_distance = current_distance
        
        return self.best_solution, self.best_distance

# %%
# Map baru untuk Tabu Search
m4 = folium.Map(location=pool, zoom_start=12)
folium.Marker(location=pool, popup='Pool Tanjungsari', icon=folium.Icon(color='red')).add_to(m4)
folium.Marker(location=tpa, popup='TPA Benowo', icon=folium.Icon(color='green')).add_to(m4)

# Implementasi Tabu Search untuk setiap cluster
print("=== TABU SEARCH RESULTS ===")
total_distance_tabu = 0

for vid in range(n_vehicles):
    cluster_pts = coords[kmeans.labels_ == vid]
    if len(cluster_pts) == 0:
        continue

    pts_list = [tuple(pt) for pt in cluster_pts]
    capacities = [coord_to_capacity[pt] for pt in pts_list]
    total_volume = sum(capacities)

    # Pilih truk terkecil yang muat
    truk_terpilih = None
    for _, row in df_truk.iterrows():
        if total_volume <= row['Volume (m^3)']:
            truk_terpilih = row
            break
    if truk_terpilih is None:
        truk_terpilih = df_truk.iloc[-1]  # Gunakan terbesar jika semuanya tidak cukup

    # Jalankan Tabu Search
    if len(pts_list) > 1:
        tabu_search = TabuSearch(
            points=pts_list,
            capacities=capacities,
            max_vehicle_capacity=truk_terpilih['Volume (m^3)'],
            tabu_tenure=7,
            max_iterations=50
        )
        
        best_routes, best_distance = tabu_search.solve()
        
        # Visualisasi semua rute untuk kendaraan ini
        vehicle_colors = ['darkred', 'orange', 'purple', 'darkgreen', 'pink']
        
        for route_idx, route in enumerate(best_routes):
            if route:
                # Konversi indeks ke koordinat aktual
                route_coords = [pts_list[i] for i in route]
                full_route = [pool] + route_coords + [tpa, pool]
                
                # Warna untuk sub-rute
                color = vehicle_colors[route_idx % len(vehicle_colors)] if len(best_routes) > 1 else colors[vid % len(colors)]
                
                folium.PolyLine(
                    locations=full_route,
                    color=color,
                    weight=3,
                    opacity=0.8,
                    popup=f'Vehicle {vid+1} Route {route_idx+1}'
                ).add_to(m4)
        
        total_distance_tabu += best_distance
        
        # Output hasil
        path_names_all = []
        for route_idx, route in enumerate(best_routes):
            route_coords = [pts_list[i] for i in route]
            route_names = [coord_to_name.get(c, 'Unknown') for c in [pool] + route_coords + [tpa, pool]]
            path_names_all.append(f"Route {route_idx+1}: " + " → ".join(route_names))
        
        print(f"[TABU] Vehicle {vid+1}:")
        for path_name in path_names_all:
            print(f"  {path_name}")
        print(f"  Total distance: {best_distance/1000:.2f} km")
        print(f"  Total volume sampah: {total_volume:.1f} m^3")
        print(f"  Jenis truk yang digunakan: {truk_terpilih['Jenis Kendaraan']} (kapasitas {truk_terpilih['Volume (m^3)']} m^3)")
     
print(f"TOTAL DISTANCE (TABU SEARCH): {total_distance_tabu/1000:.2f} km")

# Tampilkan map
m4
# Out:
# === TABU SEARCH RESULTS ===
# [TABU] Vehicle 1:
#   Route 1: Pool Tanjungsari → Kedondong → Keputran Selatan → Dinoyo → Rumah Sakit Darmo / Ketampon → Pandegiling → Pasar Kembang → TPA Benowo → Pool Tanjungsari
#   Total distance: 33.06 km
#   Total volume sampah: 11.0 m^3
#   Jenis truk yang digunakan: Truk 3.5 Ton (kapasitas 12 m^3)
# [TABU] Vehicle 2:
#   Route 1: Pool Tanjungsari → Gayungsari → Giyu → TPA Benowo → Pool Tanjungsari
#   Total distance: 42.20 km
#   Total volume sampah: 4.0 m^3
#   Jenis truk yang digunakan: Truk Kecil (kapasitas 7 m^3)
# [TABU] Vehicle 3:
#   Route 1: Pool Tanjungsari → Kendung → Alas Malang → Babat Jerawat → TPA Benowo → Pool Tanjungsari
#   Total distance: 22.50 km
#   Total volume sampah: 8.0 m^3
#   Jenis truk yang digunakan: Truk 3.5 Ton (kapasitas 12 m^3)
# [TABU] Vehicle 4:
#   Route 1: Pool Tanjungsari → Kayun → Srikana → Gubeng → Pacar Keling → Legundi Anggrek → TPA Benowo → Pool Tanjungsari
#   Total distance: 36.18 km
#   Total volume sampah: 15.0 m^3
#   Jenis truk yang digunakan: Arm Roll Truck (kapasitas 18 m^3)
# [TABU] Vehicle 5:
#   Route 1: Pool Tanjungsari → 3R Jambangan → Gayung Pring → Jagir → TPA Benowo → Pool Tanjungsari
#   Total distance: 42.06 km
#   Total volume sampah: 7.0 m^3
#   Jenis truk yang digunakan: Truk Kecil (kapasitas 7 m^3)
# [TABU] Vehicle 6:
#   Route 1: Pool Tanjungsari → Keputih → Medokan Ayu → Semolowaru Bahari → Gebang Putih → TPA Benowo → Pool Tanjungsari
#   Total distance: 51.31 km
#   Total volume sampah: 8.0 m^3
#   Jenis truk yang digunakan: Truk 3.5 Ton (kapasitas 12 m^3)
# [TABU] Vehicle 7:
#   Route 1: Pool Tanjungsari → Sulung Kali → Pecindilan → Pasar Kapasan → Tambak Rejo → Simolawang → Wonokusumo Kidul → Nyamplungan → Kertopaten → TPA Benowo → Pool Tanjungsari
#   Total distance: 36.38 km
#   Total volume sampah: 27.0 m^3
#   Jenis truk yang digunakan: Arm Roll Truck (kapasitas 18 m^3)
# [TABU] Vehicle 9:
#   Route 1: Pool Tanjungsari → Demak (Kali Butuh) → Sawahan → Simpang Dukuh → Pasar Genteng → Makam Peneleh → Pringadi → Kedung Anyar → Penghela → Panghela → Dupak → TPA Benowo → Pool Tanjungsari
#   Total distance: 32.28 km
#   Total volume sampah: 32.0 m^3
#   Jenis truk yang digunakan: Arm Roll Truck (kapasitas 18 m^3)
# [TABU] Vehicle 11:
#   Route 1: Pool Tanjungsari → Prada Kali Kendal → Kaiser → TPA Benowo → Pool Tanjungsari
#   Total distance: 25.46 km
#   Total volume sampah: 6.0 m^3
#   Jenis truk yang digunakan: Truk Kecil (kapasitas 7 m^3)
# TOTAL DISTANCE (TABU SEARCH): 321.43 km
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9ef1fc7fb4aaa7959b19c4cde7d24363 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9ef1fc7fb4aaa7959b19c4cde7d24363&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9ef1fc7fb4aaa7959b19c4cde7d24363 = L.map(
#                 &quot;map_9ef1fc7fb4aaa7959b19c4cde7d24363&quot;,
#                 {
#                     center: [-7.26053139, 112.692194],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a353512249aa000262df39700ae34387 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a353512249aa000262df39700ae34387.addTo(map_9ef1fc7fb4aaa7959b19c4cde7d24363);
#
#
#             var marker_ed835ca6908a798e64fdcbfa8b04ed36 = L.marker(
#                 [-7.26053139, 112.692194],
#                 {
# }
#             ).addTo(map_9ef1fc7fb4aaa7959b19c4cde7d24363);
#
#
#             var icon_30e5363828236d6ee46c3f095cdb4783 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_f3a4fe06c6ddbbb7b31e79e9a01091fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68b0406d01d80eeee49c87c7c957f2d2 = $(`&lt;div id=&quot;html_68b0406d01d80eeee49c87c7c957f2d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pool Tanjungsari&lt;/div&gt;`)[0];
#                 popup_f3a4fe06c6ddbbb7b31e79e9a01091fd.setContent(html_68b0406d01d80eeee49c87c7c957f2d2);
#
#
#
#         marker_ed835ca6908a798e64fdcbfa8b04ed36.bindPopup(popup_f3a4fe06c6ddbbb7b31e79e9a01091fd)
#         ;
#
#
#
#
#                 marker_ed835ca6908a798e64fdcbfa8b04ed36.setIcon(icon_30e5363828236d6ee46c3f095cdb4783);
#
#
#             var marker_908e38f90cf83893b1f8e0524a353512 = L.marker(
#                 [-7.237391, 112.609436],
#                 {
# }
#             ).addTo(map_9ef1fc7fb4aaa7959b19c4cde7d24363);
#
#
#             var icon_298d7bc47e5bd274364936c0e21f3ff3 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_aea1bbb94741716d4c88192c1926a49e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da54f00998778dbd05d4c38639d06b09 = $(`&lt;div id=&quot;html_da54f00998778dbd05d4c38639d06b09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;TPA Benowo&lt;/div&gt;`)[0];
#                 popup_aea1bbb94741716d4c88192c1926a49e.setContent(html_da54f00998778dbd05d4c38639d06b09);
#
#
#
#         marker_908e38f90cf83893b1f8e0524a353512.bindPopup(popup_aea1bbb94741716d4c88192c1926a49e)
#         ;
#
#
#
#
#                 marker_908e38f90cf83893b1f8e0524a353512.setIcon(icon_298d7bc47e5bd274364936c0e21f3ff3);
#
#
#             var poly_line_5cab9fc25795fc6f7bcda2554ea1769c = L.polyline(
#                 [[-7.26053139, 112.692194], [-7.271773, 112.738242], [-7.274575, 112.74337], [-7.278275, 112.743403], [-7.287677, 112.736963], [-7.276231, 112.735806], [-7.269049, 112.729097], [-7.237391, 112.609436], [-7.26053139, 112.692194]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9ef1fc7fb4aaa7959b19c4cde7d24363);
#
#
#         var popup_1d34e7896cb317fa2ba8188874de35e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aaa54d36ce15c102219954a49ebbfccd = $(`&lt;div id=&quot;html_aaa54d36ce15c102219954a49ebbfccd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vehicle 1 Route 1&lt;/div&gt;`)[0];
#                 popup_1d34e7896cb317fa2ba8188874de35e1.setContent(html_aaa

# %% [markdown]
# # VRP WITH SIMULATED ANNEALING

# %%
#SA Function
def simulated_annealing(points, volumes, capacity, initial_temp=500, cooling_rate=0.98, stop_temp=10):
    from functools import lru_cache

    n = len(points)
    current = list(range(n))
    random.shuffle(current)

    def total_distance(route):
        dist = 0
        prev = pool
        for idx in route:
            dist += haversine(prev, points[idx])
            prev = points[idx]
        dist += haversine(prev, tpa) + haversine(tpa, pool)
        return dist

    def is_valid(route):
        load = 0
        for i in route:
            load += volumes[i]
            if load > capacity:
                return False
        return True

    # Cari solusi awal yang valid
    tries = 0
    while not is_valid(current):
        random.shuffle(current)
        tries += 1
        if tries > 1000:
            raise Exception("Gagal mendapatkan solusi awal yang valid")

    best = current[:]
    best_dist = total_distance(best)
    temp = initial_temp
    iter_count = 0

    while temp > stop_temp:
        iter_count += 1
        neighbor = current[:]
        i, j = random.sample(range(n), 2)
        neighbor[i], neighbor[j] = neighbor[j], neighbor[i]

        if not is_valid(neighbor):
            temp *= cooling_rate
            continue

        curr_dist = total_distance(current)
        neighbor_dist = total_distance(neighbor)
        delta = neighbor_dist - curr_dist

        if delta < 0 or math.exp(-delta / temp) > random.random():
            current = neighbor
            if neighbor_dist < best_dist:
                best = neighbor[:]
                best_dist = neighbor_dist

        temp *= cooling_rate

        if iter_count % 100 == 0:
            print(f"  Iterasi {iter_count}, suhu: {temp:.2f}, best: {best_dist/1000:.2f} km")

    return [points[i] for i in best]

# %%
# Map baru untuk Simulated Annealing
m5 = folium.Map(location=pool, zoom_start=12)
folium.Marker(location=pool, popup='Pool Tanjungsari', icon=folium.Icon(color='red')).add_to(m5)
folium.Marker(location=tpa, popup='TPA Benowo', icon=folium.Icon(color='green')).add_to(m5)

# Implementasi Simulated Annealing untuk setiap cluster
print("=== SIMULATED ANNEALING RESULTS ===")
total_distance_sa = 0

for vid in range(n_vehicles):
    cluster_pts = coords[kmeans.labels_ == vid]
    if len(cluster_pts) == 0:
        continue

    pts_list = [tuple(pt) for pt in cluster_pts]
    capacities = [coord_to_capacity[pt] for pt in pts_list]
    total_volume = sum(capacities)

    # Pilih truk terkecil yang muat
    truk_terpilih = None
    for _, row in df_truk.iterrows():
        if total_volume <= row['Volume (m^3)']:
            truk_terpilih = row
            break
    if truk_terpilih is None:
        truk_terpilih = df_truk.iloc[-1]  # Gunakan terbesar jika semuanya tidak cukup

    # Jalankan Simulated Annealing
    if len(pts_list) > 1:
        print(f"\n[SA] Processing Vehicle {vid+1} with {len(pts_list)} stops...")
        try:
            best_route = simulated_annealing(
                points=pts_list,
                volumes=capacities,
                capacity=truk_terpilih['Volume (m^3)'],
                initial_temp=1000,
                cooling_rate=0.95,
                stop_temp=1
            )
            
            # Hitung total jarak rute
            def calculate_total_distance(route_points):
                dist = haversine(pool, route_points[0])
                for i in range(len(route_points) - 1):
                    dist += haversine(route_points[i], route_points[i+1])
                dist += haversine(route_points[-1], tpa)
                dist += haversine(tpa, pool)
                return dist
            
            route_distance = calculate_total_distance(best_route)
            total_distance_sa += route_distance
            
            # Bangun rute lengkap untuk visualisasi
            full_route = [pool] + best_route + [tpa, pool]
            color = colors[vid % len(colors)]
            
            folium.PolyLine(
                locations=full_route,
                color=color,
                weight=3,
                opacity=0.8,
                popup=f'Vehicle {vid+1} (SA)'
            ).add_to(m5)
            
            # Output hasil
            path_names = [coord_to_name.get(c, 'Unknown') for c in full_route]
            print(f"[SA] Vehicle {vid+1}: " + " → ".join(path_names))
            print(f"  Total distance: {route_distance/1000:.2f} km")
            print(f"  Total volume sampah: {total_volume:.1f} m^3")
            print(f"  Jenis truk yang digunakan: {truk_terpilih['Jenis Kendaraan']} (kapasitas {truk_terpilih['Volume (m^3)']} m^3)\n")
            
        except Exception as e:
            print(f"  Error with Vehicle {vid+1}: {e}")
            # Fallback ke rute sederhana
            simple_route = [pool] + pts_list + [tpa, pool]
            folium.PolyLine(
                locations=simple_route,
                color=colors[vid % len(colors)],
                weight=2.5,
                opacity=0.8,
                popup=f'Vehicle {vid+1} (Fallback)'
            ).add_to(m5)
            
            route_distance = haversine(pool, pts_list[0])
            for i in range(len(pts_list) - 1):
                route_distance += haversine(pts_list[i], pts_list[i+1])
            route_distance += haversine(pts_list[-1], tpa) + haversine(tpa, pool)
            total_distance_sa += route_distance
            
            path_names = [coord_to_name.get(c, 'Unknown') for c in simple_route]
            print(f"[SA] Vehicle {vid+1} (Fallback): " + " → ".join(path_names))
            print(f"  Total distance: {route_distance/1000:.2f} km")
            print(f"  Total volume sampah: {total_volume:.1f} m^3")
            print(f"  Jenis truk yang digunakan: {truk_terpilih['Jenis Kendaraan']} (kapasitas {truk_terpilih['Volume (m^3)']} m^3)\n")
    
    else:
        # Hanya satu titik, buat rute sederhana
        single_route = [pool] + pts_list + [tpa, pool]
        folium.PolyLine(
            locations=single_route,
            color=colors[vid % len(colors)],
            weight=2.5,
            opacity=0.8,
            popup=f'Vehicle {vid+1}'
        ).add_to(m5)
        
        route_distance = haversine(pool, pts_list[0]) + haversine(pts_list[0], tpa) + haversine(tpa, pool)
        total_distance_sa += route_distance
        
        path_names = [coord_to_name.get(c, 'Unknown') for c in single_route]
        print(f"[SA] Vehicle {vid+1}: " + " → ".join(path_names))
        print(f"  Total distance: {route_distance/1000:.2f} km")
        print(f"  Total volume sampah: {total_volume:.1f} m^3")
        print(f"  Jenis truk yang digunakan: {truk_terpilih['Jenis Kendaraan']} (kapasitas {truk_terpilih['Volume (m^3)']} m^3)\n")

print(f"TOTAL DISTANCE (SIMULATED ANNEALING): {total_distance_sa/1000:.2f} km")

# Tampilkan map
m5
# Out:
# === SIMULATED ANNEALING RESULTS ===
#
# [SA] Processing Vehicle 1 with 6 stops...
#   Iterasi 100, suhu: 5.92, best: 32.91 km
# [SA] Vehicle 1: Pool Tanjungsari → Rumah Sakit Darmo / Ketampon → Dinoyo → Keputran Selatan → Kedondong → Pandegiling → Pasar Kembang → TPA Benowo → Pool Tanjungsari
#   Total distance: 32.91 km
#   Total volume sampah: 11.0 m^3
#   Jenis truk yang digunakan: Truk 3.5 Ton (kapasitas 12 m^3)
#
#
# [SA] Processing Vehicle 2 with 2 stops...
#   Iterasi 100, suhu: 5.92, best: 41.98 km
# [SA] Vehicle 2: Pool Tanjungsari → Giyu → Gayungsari → TPA Benowo → Pool Tanjungsari
#   Total distance: 41.98 km
#   Total volume sampah: 4.0 m^3
#   Jenis truk yang digunakan: Truk Kecil (kapasitas 7 m^3)
#
#
# [SA] Processing Vehicle 3 with 3 stops...
#   Iterasi 100, suhu: 5.92, best: 19.83 km
# [SA] Vehicle 3: Pool Tanjungsari → Alas Malang → Kendung → Babat Jerawat → TPA Benowo → Pool Tanjungsari
#   Total distance: 19.83 km
#   Total volume sampah: 8.0 m^3
#   Jenis truk yang digunakan: Truk 3.5 Ton (kapasitas 12 m^3)
#
#
# [SA] Processing Vehicle 4 with 5 stops...
#   Iterasi 100, suhu: 5.92, best: 36.27 km
# [SA] Vehicle 4: Pool Tanjungsari → Legundi Anggrek → Pacar Keling → Gubeng → Srikana → Kayun → TPA Benowo → Pool Tanjungsari
#   Total distance: 36.27 km
#   Total volume sampah: 15.0 m^3
#   Jenis truk yang digunakan: Arm Roll Truck (kapasitas 18 m^3)
#
#
# [SA] Processing Vehicle 5 with 3 stops...
#   Iterasi 100, suhu: 5.92, best: 40.35 km
# [SA] Vehicle 5: Pool Tanjungsari → Jagir → 3R Jambangan → Gayung Pring → TPA Benowo → Pool Tanjungsari
#   Total distance: 40.35 km
#   Total volume sampah: 7.0 m^3
#   Jenis truk yang digunakan: Truk Kecil (kapasitas 7 m^3)
#
#
# [SA] Processing Vehicle 6 with 4 stops...
#   Iterasi 100, suhu: 5.92, best: 50.25 km
# [SA] Vehicle 6: Pool Tanjungsari → Gebang Putih → Keputih → Medokan Ayu → Semolowaru Bahari → TPA Benowo → Pool Tanjungsari
#   Total distance: 50.25 km
#   Total volume sampah: 8.0 m^3
#   Jenis truk yang digunakan: Truk 3.5 Ton (kapasitas 12 m^3)
#
#
# [SA] Processing Vehicle 7 with 8 stops...
#   Error with Vehicle 7: Gagal mendapatkan solusi awal yang valid
# [SA] Vehicle 7 (Fallback): Pool Tanjungsari → Sulung Kali → Simolawang → Pasar Kapasan → Tambak Rejo → Pecindilan → Nyamplungan → Kertopaten → Wonokusumo Kidul → TPA Benowo → Pool Tanjungsari
#   Total distance: 40.91 km
#   Total volume sampah: 27.0 m^3
#   Jenis truk yang digunakan: Arm Roll Truck (kapasitas 18 m^3)
#
# [SA] Vehicle 8: Pool Tanjungsari → Tambak Deres → TPA Benowo → Pool Tanjungsari
#   Total distance: 39.73 km
#   Total volume sampah: 5.0 m^3
#   Jenis truk yang digunakan: Truk Kecil (kapasitas 7 m^3)
#
#
# [SA] Processing Vehicle 9 with 10 stops...
#   Error with Vehicle 9: Gagal mendapatkan solusi awal yang valid
# [SA] Vehicle 9 (Fallback): Pool Tanjungsari → Demak (Kali Butuh) → Pringadi → Penghela → Dupak → Simpang Dukuh → Pasar Genteng → Makam Peneleh → Kedung Anyar → Sawahan → Panghela → TPA Benowo → Pool Tanjungsari
#   Total distance: 36.25 km
#   Total volume sampah: 32.0 m^3
#   Jenis truk yang digunakan: Arm Roll Truck (kapasitas 18 m^3)
#
# [SA] Vehicle 10: Pool Tanjungsari → Pesapen → TPA Benowo → Pool Tanjungsari
#   Total distance: 29.32 km
#   Total volume sampah: 2.0 m^3
#   Jenis truk yang digunakan: Truk Kecil (kapasitas 7 m^3)
#
#
# [SA] Processing Vehicle 11 with 2 stops...
#   Iterasi 100, suhu: 5.92, best: 24.80 km
# [SA] Vehicle 11: Pool Tanjungsari → Kaiser → Prada Kali Kendal → TPA Benowo → Pool Tanjungsari
#   Total distance: 24.80 km
#   Total volume sampah: 6.0 m^3
#   Jenis truk yang digunakan: Truk Kecil (kapasitas 7 m^3)
#
# TOTAL DISTANCE (SIMULATED ANNEALING): 392.60 km
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a8186f1a96b334f4a6f8f380d798af1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a8186f1a96b334f4a6f8f380d798af1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a8186f1a96b334f4a6f8f380d798af1 = L.map(
#                 &quot;map_0a8186f1a96b334f4a6f8f380d798af1&quot;,
#                 {
#                     center: [-7.26053139, 112.692194],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_790e569e00a38152613e181c62ce7243 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_790e569e00a38152613e181c62ce7243.addTo(map_0a8186f1a96b334f4a6f8f380d798af1);
#
#
#             var marker_e6b5372da9ae848c1051c5d6de791fa3 = L.marker(
#                 [-7.26053139, 112.692194],
#                 {
# }
#             ).addTo(map_0a8186f1a96b334f4a6f8f380d798af1);
#
#
#             var icon_5727978d75dcc9ddb0c7e7a5c960e4bb = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_821779f822d964e863ee8572c2a7ea99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9186fd86fe0064e6eac92f69ad52f3e3 = $(`&lt;div id=&quot;html_9186fd86fe0064e6eac92f69ad52f3e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pool Tanjungsari&lt;/div&gt;`)[0];
#                 popup_821779f822d964e863ee8572c2a7ea99.setContent(html_9186fd86fe0064e6eac92f69ad52f3e3);
#
#
#
#         marker_e6b5372da9ae848c1051c5d6de791fa3.bindPopup(popup_821779f822d964e863ee8572c2a7ea99)
#         ;
#
#
#
#
#                 marker_e6b5372da9ae848c1051c5d6de791fa3.setIcon(icon_5727978d75dcc9ddb0c7e7a5c960e4bb);
#
#
#             var marker_1f1283c357164af29ce1c1709333ce46 = L.marker(
#                 [-7.237391, 112.609436],
#                 {
# }
#             ).addTo(map_0a8186f1a96b334f4a6f8f380d798af1);
#
#
#             var icon_5ca520a39c6d01ad41f1ed107c088524 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_6167018c51ce9a7998027659e3110975 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4d238e1e9e3eb9764fb1e79184da7a6 = $(`&lt;div id=&quot;html_a4d238e1e9e3eb9764fb1e79184da7a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;TPA Benowo&lt;/div&gt;`)[0];
#                 popup_6167018c51ce9a7998027659e3110975.setContent(html_a4d238e1e9e3eb9764fb1e79184da7a6);
#
#
#
#         marker_1f1283c357164af29ce1c1709333ce46.bindPopup(popup_6167018c51ce9a7998027659e3110975)
#         ;
#
#
#
#
#                 marker_1f1283c357164af29ce1c1709333ce46.setIcon(icon_5ca520a39c6d01ad41f1ed107c088524);
#
#
#             var poly_line_771142f9d600c4b47e9ffcdc0f73f600 = L.polyline(
#                 [[-7.26053139, 112.692194], [-7.287677, 112.736963], [-7.278275, 112.743403], [-7.274575, 112.74337], [-7.271773, 112.738242], [-7.276231, 112.735806], [-7.269049, 112.729097], [-7.237391, 112.609436], [-7.26053139, 112.692194]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0a8186f1a96b334f4a6f8f380d798af1);
#
#
#         var popup_1ec40e37948e1cc9bcb66b7b8e2e013f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8327604802cb020efcd529d02ea6acd = $(`&lt;div id=&quot;html_b8327604802cb020efcd529d02ea6acd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vehicle 1 (SA)&lt;/div&gt;`)[0];
#                 popup_1ec40e37948e1cc9bcb66b7b8e2e013f.setContent(html_b83276

# %% [markdown]
# # Final Algorithm Comparison

# %%
# Bandingkan hasil semua algoritma
print("=== COMPREHENSIVE ALGORITHM COMPARISON ===")
print("\n1. Genetic Algorithm (GA):")
print("   - Menggunakan crossover dan mutasi untuk evolusi populasi")
print("   - Baik untuk eksplorasi ruang solusi yang luas")
print("   - Tidak mempertimbangkan kapasitas kendaraan secara eksplisit")

print("\n2. Ant Colony Optimization (ACO):")
print("   - Menggunakan pheromone trails untuk mencari jalur optimal")
print(f"   - Total distance: {total_distance_aco/1000:.2f} km")
print("   - Terinspirasi dari perilaku koloni semut")
print("   - Mempertimbangkan kapasitas kendaraan dalam pemilihan truk")

print("\n3. Tabu Search:")
print("   - Menggunakan memori tabu untuk menghindari local optima")
print("   - Melakukan pencarian lokal dengan pembatasan gerakan")
print(f"   - Total distance: {total_distance_tabu/1000:.2f} km")
print("   - Dapat membuat multiple sub-routes per kendaraan")
print("   - Mempertimbangkan kapasitas kendaraan secara ketat")

print("\n4. Simulated Annealing (SA):")
print("   - Menggunakan probabilitas penerimaan solusi yang menurun")
print("   - Dapat menerima solusi yang lebih buruk untuk menghindari local optima")
print(f"   - Total distance: {total_distance_sa/1000:.2f} km")
print("   - Mempertimbangkan kapasitas kendaraan dengan validasi ketat")

print("\n=== SUMMARY ===")
print("Semua algoritma menggunakan:")
print("- K-Means clustering untuk pembagian wilayah (11 kendaraan)")
print("- Data kapasitas sampah dari new_data.csv")
print("- Data kapasitas truk dari kapasitas-truk.csv")
print("- Rute: Pool Tanjungsari → TPS/Depo → TPA Benowo → Pool Tanjungsari")

print("\nPerbandingan Total Jarak:")
print(f"- Ant Colony Optimization: {total_distance_aco/1000:.2f} km")
print(f"- Tabu Search: {total_distance_tabu/1000:.2f} km")
print(f"- Simulated Annealing: {total_distance_sa/1000:.2f} km")

# Tentukan algoritma terbaik
algo_results = {
    # "Genetic Algorithm": float('inf'),  # Belum dihitung dengan constraint kapasitas
    "Ant Colony Optimization": total_distance_aco,
    "Tabu Search": total_distance_tabu,
    "Simulated Annealing": total_distance_sa
}
# Temukan algoritma dengan total distance paling kecil
best_algo = min(algo_results, key=algo_results.get)
best_distance = algo_results[best_algo]
print(f"\nAlgoritma terbaik: {best_algo} dengan total jarak {best_distance/1000:.2f} km")
# Out:
# === COMPREHENSIVE ALGORITHM COMPARISON ===
#
# 1. Genetic Algorithm (GA):
#    - Menggunakan crossover dan mutasi untuk evolusi populasi
#    - Baik untuk eksplorasi ruang solusi yang luas
#    - Tidak mempertimbangkan kapasitas kendaraan secara eksplisit
#
# 2. Ant Colony Optimization (ACO):
#    - Menggunakan pheromone trails untuk mencari jalur optimal
#    - Total distance: 383.88 km
#    - Terinspirasi dari perilaku koloni semut
#    - Mempertimbangkan kapasitas kendaraan dalam pemilihan truk
#
# 3. Tabu Search:
#    - Menggunakan memori tabu untuk menghindari local optima
#    - Melakukan pencarian lokal dengan pembatasan gerakan
#    - Total distance: 321.43 km
#    - Dapat membuat multiple sub-routes per kendaraan
#    - Mempertimbangkan kapasitas kendaraan secara ketat
#
# 4. Simulated Annealing (SA):
#    - Menggunakan probabilitas penerimaan solusi yang menurun
#    - Dapat menerima solusi yang lebih buruk untuk menghindari local optima
#    - Total distance: 392.60 km
#    - Mempertimbangkan kapasitas kendaraan dengan validasi ketat
#
# === SUMMARY ===
# Semua algoritma menggunakan:
# - K-Means clustering untuk pembagian wilayah (11 kendaraan)
# - Data kapasitas sampah dari new_data.csv
# - Data kapasitas truk dari kapasitas-truk.csv
# - Rute: Pool Tanjungsari → TPS/Depo → TPA Benowo → Pool Tanjungsari
#
# Perbandingan Total Jarak:
# - Ant Colony Optimization: 383.88 km
# - Tabu Search: 321.43 km
# - Simulated Annealing: 392.60 km
#
# Algoritma terbaik: Tabu Search dengan total jarak 321.43 km
