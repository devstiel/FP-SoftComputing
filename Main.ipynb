# %% [markdown]
# # Optimasi Vehicle Routing Problem <br> Alur Pembuangan Sampah Rayon Surabaya Pusat
# <b> Kelompok 08 </b> <br>
# Nama Anggota :
# 1. Nida Aulia Amartika			(5026221095)
# 2. Isaura Qinthara Heriswan		(5026221146)
# 3. Devy Relliani Saffiyah		(5026221189)

# %% [markdown]
# # Exploratory Data Analysis

# %%
# %pip install scikit-learn
# %pip install folium
# Out:
# Requirement already satisfied: scikit-learn in c:\users\devy relliani\appdata\local\programs\python\python313\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\devy relliani\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\devy relliani\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\devy relliani\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\devy relliani\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting folium
#   Downloading folium-0.19.7-py2.py3-none-any.whl.metadata (4.1 kB)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.8.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\devy relliani\appdata\local\programs\python\python313\lib\site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in c:\users\devy relliani\appdata\local\programs\python\python313\lib\site-packages (from folium) (2.2.6)
# Requirement already satisfied: requests in c:\users\devy relliani\appdata\local\programs\python\python313\lib\site-packages (from folium) (2.32.3)
# Collecting xyzservices (from folium)
#   Downloading xyzservices-2025.4.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\devy relliani\appdata\local\programs\python\python313\lib\site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\devy relliani\appdata\local\programs\python\python313\lib\site-packages (from requests->folium) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\devy relliani\appdata\local\programs\python\python313\lib\site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\devy relliani\appdata\local\programs\python\python313\lib\site-packages (from requests->folium) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\devy relliani\appdata\local\programs\python\python313\lib\site-packages (from requests->folium) (2025.4.26)
# Downloading folium-0.19.7-py2.py3-none-any.whl (112 kB)
# Downloading branca-0.8.1-py3-none-any.whl (26 kB)
# Downloading xyzservices-2025.4.0-py3-none-any.whl (90 kB)
# Installing collected packages: xyzservices, branca, folium
#
#    ------------- -------------------------- 1/3 [branca]
#    -------------------------- ------------- 2/3 [folium]
#    -------------------------- ------------- 2/3 [folium]
#    -------------------------- ------------- 2/3 [folium]
#    -------------------------- ------------- 2/3 [folium]
#    -------------------------- ------------- 2/3 [folium]
#    -------------------------- ------------- 2/3 [folium]
#    -------------------------- ------------- 2/3 [folium]
#    ---------------------------------------- 3/3 [folium]
#
# Successfully installed branca-0.8.1 folium-0.19.7 xyzservices-2025.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import random
from sklearn.cluster import KMeans
import folium
import math

# %%
df = pd.read_csv('new_data.csv')
df
# Out:
#     No                      LPS/Depo                                Alamat  \
# 0    1            Demak (Kali Butuh)                           Jalan Demak
# 1    2                      Pringadi                        Jalan Pringadi
# 2    3                      Penghela                        Jalan Penghela
# 3    4                   Sulung Kali                     Jalan Sulung Kali
# 4    5                         Dupak                   Jalan Babatan Dupak
# 5    6                    Simolawang                      Jalan Simolawang
# 6    7                 Pasar Kapasan               Jalan Simolawang Baru I
# 7    8                   Tambak Rejo  Jalan Kenjeran (depan Makam Rangkah)
# 8    9                 Simpang Dukuh                   Jalan Simpang Dukuh
# 9   10                 Pasar Genteng                   Jalan Genteng Besar
# 10  11                         Kayun                           Jalan Kayun
# 11  12               Legundi Anggrek                         Jalan Anggrek
# 12  13                    Pecindilan                 Jalan Raya Pecindilan
# 13  14                 Makam Peneleh                   Jalan Makam Peneleh
# 14  15                     Kedondong                       Jalan Kedondong
# 15  16                  Kedung Anyar                    Jalan Kedung Anyar
# 16  17                 Pasar Kembang              Jalan Wonorejo III Pasar
# 17  18                   Pandegiling                     Jalan Pandegiling
# 18  19                        Dinoyo                          Jalan Dinoyo
# 19  20  Rumah Sakit Darmo / Ketampon                  Jalan Taman Ketampon
# 20  21              Keputran Selatan                Jalan Keputran Selatan
# 21  22                  3R Jambangan           Jalan Jambangan Kebon Agung
# 22  23                    Gayungsari                   Jalan Gayungsari IV
# 23  24                   Nyamplungan                  Jalan KH Mas Mansyur
# 24  25                    Kertopaten                      Jalan Kertopaten
# 25  26                         Jagir                   Jalan Bendul Merisi
# 26  27             Prada Kali Kendal                     Jalan Kali Kendal
# 27  28              Wonokusumo Kidul                 Jalan Wonokusumo Jaya
# 28  29                        Gubeng                Jalan Gubeng Kertajaya
# 29  30                       Sawahan                    Jalan Sawahan Raya
# 30  31                       Kendung                         Jalan Kendung
# 31  32                         Kayon                           Jalan Kayon
# 32  33                      Panghela                        Jalan Panghela
# 33  34                          Giyu                Jalan Rungkut Industri
# 34  35                   Alas Malang                     Jalan Alas Malang
# 35  36                 Babat Jerawat                      Jalan DK Jerawat
# 36  37                       Srikana                         Jalan Srikana
# 37  38                       Keputih                Jalan Raya Marina Asri
# 38  39                  Tambak Deres               Jalan Kyai Tambak Deres
# 39  40                  Pacar Keling                    Jalan Tambang Boyo
# 40  41                        Kaiser                           Jalan Makam
# 41  42                   Medokan Ayu             Jalan Medokan Asri Tengah
# 42  43             Semolowaru Bahari                      Jalan Semolowaru
# 43  44                  Gebang Putih                    Jalan Gebang Putih
# 44  45                       Pesapen                    Jalan Karang Ploso
#
#     Latitude   Longitude
# 0  -7.253606  112.720422
# 1  -7.252544  112.733072
# 2  -7.248233  112.733186
# 3  -7.244014  112.742173
# 4  -7.244836  112.727439
# 5  -7.237522  112.753542
# 6  -7.239633  112.750247
# 7  -7.243069  112.760314
# 8  -7.260503  112.742111
# 9  -7.258242  112.740377
# 10 -7.269259  112.747528
# 11 -7.262483  112.752017
# 12 -7.244094  112.747411
# 13 -7.252331  112.741364
# 14 -7.271773  112.738242
# 15 -7.254253  112.731048
# 16 -7.269049  112.729097
# 17 -7.276231  112.735806
# 18 -7.278275  112.743403
# 19 -7.287677  112.736963
# 20 -7.274575  112.743370
# 21 -7.313541  112.732069
# 22 -7.324832  112.749814
# 23 -7.221696  112.750527
# 24 -7.230313  112.741019
# 25 -7.299018  112.753697
# 26 -7.275311  112.695040
# 27 -7.225113  112.752340
# 28 -7.277812  112.761476
# 29 -7.262594  112.728107
# 30 -7.247601  112.635484
# 31 -7.269131  112.747705
# 32 -7.247908  112.733304
# 33 -7.331003  112.771393
# 34 -7.262228  112.643165
# 35 -7.246167  112.629661
# 36 -7.273996  112.758097
# 37 -7.294823  112.807148
# 38 -7.230860  112.785501
# 39 -7.260621  112.758661
# 40 -7.276720  112.713377
# 41 -7.326099  112.795516
# 42 -7.302239  112.788335
# 43 -7.284392  112.785407
# 44 -7.326542  112.674600

# %%
pool = (-7.26053139, 112.692194)   # Pool Tanjungsari
tpa  = (-7.23739100, 112.60943600) # TPA Benowo

# %%
m1 = folium.Map(location=pool, zoom_start=12)
folium.Marker(location=pool, popup='Pool Tanjungsari', icon=folium.Icon(color='red')).add_to(m1)
folium.Marker(location=tpa, popup='TPA Benowo', icon=folium.Icon(color='green')).add_to(m1)
for _, row in df.iterrows():
    folium.Marker(location=(row['Latitude'], row['Longitude']), popup=row['LPS/Depo']).add_to(m1)
m1  # Preview map before VRP
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_21421302e12fdef1096be52912635d6e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_21421302e12fdef1096be52912635d6e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_21421302e12fdef1096be52912635d6e = L.map(
#                 &quot;map_21421302e12fdef1096be52912635d6e&quot;,
#                 {
#                     center: [-7.26053139, 112.692194],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b54ff9ddbdd6fdc4774a7eb4669456c6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b54ff9ddbdd6fdc4774a7eb4669456c6.addTo(map_21421302e12fdef1096be52912635d6e);
#
#
#             var marker_c0af3a8b68a70dc5774be4ec3b92451c = L.marker(
#                 [-7.26053139, 112.692194],
#                 {
# }
#             ).addTo(map_21421302e12fdef1096be52912635d6e);
#
#
#             var icon_652641007282d3d0fd6225a098b5371d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_7fc262ec004a91c1141a67e0bfd7ca7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_331dd6a6f165f79f1872e17b6eeac6dd = $(`&lt;div id=&quot;html_331dd6a6f165f79f1872e17b6eeac6dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pool Tanjungsari&lt;/div&gt;`)[0];
#                 popup_7fc262ec004a91c1141a67e0bfd7ca7e.setContent(html_331dd6a6f165f79f1872e17b6eeac6dd);
#
#
#
#         marker_c0af3a8b68a70dc5774be4ec3b92451c.bindPopup(popup_7fc262ec004a91c1141a67e0bfd7ca7e)
#         ;
#
#
#
#
#                 marker_c0af3a8b68a70dc5774be4ec3b92451c.setIcon(icon_652641007282d3d0fd6225a098b5371d);
#
#
#             var marker_203f1be3ad408d12d30edb3fa1e499b2 = L.marker(
#                 [-7.237391, 112.609436],
#                 {
# }
#             ).addTo(map_21421302e12fdef1096be52912635d6e);
#
#
#             var icon_3fb5698939a2e03c33752421ec6400bc = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4d0e742d265d7a7079d8778bde20809b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae82ab93bc24107a501bdc44d4057890 = $(`&lt;div id=&quot;html_ae82ab93bc24107a501bdc44d4057890&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;TPA Benowo&lt;/div&gt;`)[0];
#                 popup_4d0e742d265d7a7079d8778bde20809b.setContent(html_ae82ab93bc24107a501bdc44d4057890);
#
#
#
#         marker_203f1be3ad408d12d30edb3fa1e499b2.bindPopup(popup_4d0e742d265d7a7079d8778bde20809b)
#         ;
#
#
#
#
#                 marker_203f1be3ad408d12d30edb3fa1e499b2.setIcon(icon_3fb5698939a2e03c33752421ec6400bc);
#
#
#             var marker_1020ebfbc9282fc3cd2d6629b0051e42 = L.marker(
#                 [-7.253606, 112.720422],
#                 {
# }
#             ).addTo(map_21421302e12fdef1096be52912635d6e);
#
#
#         var popup_d873a017416da74a14e288c631d19797 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1ff4538af345ebeb00c053f1bb24a0c = $(`&lt;div id=&quot;html_e1ff4538af345ebeb00c053f1bb24a0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Demak (Kali Butuh)&lt;/div&gt;`)[0];
#                 popup_d873a017416da74a14e288c631d19797.setContent(html_e1ff4538af345ebeb00c053f1bb24a0c);
#
#
#
#         marker_1020ebfbc9282fc3cd2d6629b0051e42.bindPopup(popup_d873a017416da74a14e288c631d19797)
#         ;
#
#
#
#
#             var marker_f8bcd653b05a19b5683bdf9200f51650 = L.marker(
#                 [-7.252544, 112.733072],
#                 {
# }
#             ).addTo(map_21421302e12fdef1096be52912635d6e);
#
#
#         var popup_62762ba369b5d8ad4e707619fa098854 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d32302580bce6ed3c0cf457f6f46e58 = $(`&lt;div id=&quot;html_3d32302580bce6ed3c0cf457f6f46e58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;P

# %%
n_vehicles = 11
coords = df[['Latitude','Longitude']].values
kmeans = KMeans(n_clusters=n_vehicles, random_state=42).fit(coords)
df['cluster'] = kmeans.labels_

# %%
colors = ['blue', 'purple', 'orange', 'yellow', 'lightred', 'darkblue', 'darkgreen', 'cadetblue', 'darkpurple', 'pink', 'lightblue']

# Create a new map centered at the pool
m_cluster = folium.Map(location=pool, zoom_start=12)

# Add depot and TPA markers
folium.Marker(location=pool, popup='Pool Tanjungsari', icon=folium.Icon(color='red')).add_to(m_cluster)
folium.Marker(location=tpa, popup='TPA Benowo', icon=folium.Icon(color='green')).add_to(m_cluster)

# Add markers for each point, colored by cluster
for _, row in df.iterrows():
    folium.Marker(location=(row['Latitude'], row['Longitude']),
                  popup=f"{row['LPS/Depo']} (Cluster {row['cluster']})",
                  icon=folium.Icon(color=colors[row['cluster'] % len(colors)])).add_to(m_cluster)

# Display the map
m_cluster
# Out:
# C:\Users\Devy Relliani\AppData\Local\Temp\ipykernel_10488\1510036970.py:14: UserWarning: color argument of Icon should be one of: {'lightblue', 'lightred', 'lightgreen', 'black', 'lightgray', 'darkred', 'white', 'darkblue', 'cadetblue', 'darkgreen', 'green', 'red', 'darkpurple', 'purple', 'orange', 'blue', 'gray', 'beige', 'pink'}.
#   icon=folium.Icon(color=colors[row['cluster'] % len(colors)])).add_to(m_cluster)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f1ca13e94f67ef25685ed3defdca344b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f1ca13e94f67ef25685ed3defdca344b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f1ca13e94f67ef25685ed3defdca344b = L.map(
#                 &quot;map_f1ca13e94f67ef25685ed3defdca344b&quot;,
#                 {
#                     center: [-7.26053139, 112.692194],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cd454b50a56fe6b47688be23c1437780 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cd454b50a56fe6b47688be23c1437780.addTo(map_f1ca13e94f67ef25685ed3defdca344b);
#
#
#             var marker_6de678968df842fefb6307c1b0bd4ff7 = L.marker(
#                 [-7.26053139, 112.692194],
#                 {
# }
#             ).addTo(map_f1ca13e94f67ef25685ed3defdca344b);
#
#
#             var icon_83871e7e6d5c1acece31ecfca5d6054b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_de45024f83b8d23c71a36bc4b27ad543 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71cc92dbdc193cd98f63261579e247b8 = $(`&lt;div id=&quot;html_71cc92dbdc193cd98f63261579e247b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pool Tanjungsari&lt;/div&gt;`)[0];
#                 popup_de45024f83b8d23c71a36bc4b27ad543.setContent(html_71cc92dbdc193cd98f63261579e247b8);
#
#
#
#         marker_6de678968df842fefb6307c1b0bd4ff7.bindPopup(popup_de45024f83b8d23c71a36bc4b27ad543)
#         ;
#
#
#
#
#                 marker_6de678968df842fefb6307c1b0bd4ff7.setIcon(icon_83871e7e6d5c1acece31ecfca5d6054b);
#
#
#             var marker_f7b714f24ab037353b8b7b871f54d7c0 = L.marker(
#                 [-7.237391, 112.609436],
#                 {
# }
#             ).addTo(map_f1ca13e94f67ef25685ed3defdca344b);
#
#
#             var icon_ba889ed9dbca897243fcc8a802e8b478 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_20e49bf4fdc88b26287a60297cc19b0a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63f018f24e60ddd0590102769095320b = $(`&lt;div id=&quot;html_63f018f24e60ddd0590102769095320b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;TPA Benowo&lt;/div&gt;`)[0];
#                 popup_20e49bf4fdc88b26287a60297cc19b0a.setContent(html_63f018f24e60ddd0590102769095320b);
#
#
#
#         marker_f7b714f24ab037353b8b7b871f54d7c0.bindPopup(popup_20e49bf4fdc88b26287a60297cc19b0a)
#         ;
#
#
#
#
#                 marker_f7b714f24ab037353b8b7b871f54d7c0.setIcon(icon_ba889ed9dbca897243fcc8a802e8b478);
#
#
#             var marker_f1284eb9a34a29ca6c198d1c25fb6f06 = L.marker(
#                 [-7.253606, 112.720422],
#                 {
# }
#             ).addTo(map_f1ca13e94f67ef25685ed3defdca344b);
#
#
#             var icon_3476940f0e665a41c6d2cfbe17fb5a59 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;yellow&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_387c43b5cdc1e37f31133091398ee7ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9a409e2bc6a9aeb59e4b8f9dee00317 = $(`&lt;div id=&quot;html_f9a409e2bc6a9aeb59e4b8f9dee00317&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Demak (Kali Butuh) (Cluster 3)&lt;/div&gt;`)[0];
#                 popup_387c43b5cdc1e37f31133091398ee7ff.setContent(html_f9a409e2bc6a9aeb59e4b8f9dee00317);
#
#
#
#         marker_f1284eb9a34a29ca6c198d1c25fb6f06.bindPopup(popup_387c43b5cdc1e37f31133091398ee7ff)
#         ;
#
#
#
#
#                 marker_f1284eb9a34a29ca6c198d1c25fb6f06.setIcon(icon_3476940f0e665a41c6d2cfbe17fb5a59);
#
#
#             var m

# %%
def haversine(a, b):
    R = 6371e3
    φ1, φ2 = math.radians(a[0]), math.radians(b[0])
    Δφ = math.radians(b[0] - a[0])
    Δλ = math.radians(b[1] - a[1])
    x = math.sin(Δφ/2)**2 + math.cos(φ1)*math.cos(φ2)*math.sin(Δλ/2)**2
    return R * 2 * math.asin(math.sqrt(x))

# %%
def route_distance(route):
    dist = 0
    prev = pool
    for pt in route:
        dist += haversine(prev, pt)
        prev = pt
    dist += haversine(prev, tpa) + haversine(tpa, pool)
    return dist

# %%
def order_crossover(p1, p2):
    size = len(p1)
    a, b = sorted(random.sample(range(size), 2))
    c1 = [None]*size
    c2 = [None]*size
    c1[a:b], c2[a:b] = p1[a:b], p2[a:b]
    def fill(child, parent):
        pos = b
        for gene in parent[b:] + parent[:b]:
            if gene not in child:
                if pos >= size: pos = 0
                child[pos] = gene
                pos += 1
    fill(c1, p2)
    fill(c2, p1)
    return c1, c2

# %%
def mutate(ind):
    if len(ind) > 1:
        i, j = random.sample(range(len(ind)), 2)
        ind[i], ind[j] = ind[j], ind[i]

# %%
def ga_cluster(points, pop_size=150, gens=800, elite_size=1):
    n = len(points)
    if n < 2:
        return points

    # initialize population
    population = [random.sample(range(n), n) for _ in range(pop_size)]

    for _ in range(gens):
        # compute fitness for roulette selection
        fitness = [1/(route_distance([points[i] for i in ind]) + 1) for ind in population]
        total = sum(fitness)
        probs = [f/total for f in fitness]

        # select elites (best individuals) to carry forward
        sorted_pop = sorted(
            population,
            key=lambda ind: route_distance([points[i] for i in ind])
        )
        new_pop = [sorted_pop[i].copy() for i in range(elite_size)]

        # fill the rest of new_pop by crossover + mutation
        while len(new_pop) < pop_size:
            # select two parents
            p1, p2 = random.choices(population, probs, k=2)
            # crossover
            if random.random() < 0.8:
                c1, c2 = order_crossover(p1, p2)
            else:
                c1, c2 = p1[:], p2[:]
            # mutate
            if random.random() < 0.2:
                mutate(c1)
            if random.random() < 0.2:
                mutate(c2)

            new_pop.append(c1)
            if len(new_pop) < pop_size:
                new_pop.append(c2)

        population = new_pop

    # return the best route as actual coordinates
    best = min(
        population,
        key=lambda ind: route_distance([points[i] for i in ind])
    )
    return [points[i] for i in best]

# %%
m2 = folium.Map(location=pool, zoom_start=12)
folium.Marker(location=pool, popup='Pool Tanjungsari', icon=folium.Icon(color='red')).add_to(m2)
folium.Marker(location=tpa, popup='TPA Benowo', icon=folium.Icon(color='green')).add_to(m2)

# Colors already defined above - no need to redefine

coord_to_name = {
    (row['Latitude'], row['Longitude']): row['LPS/Depo']
    for _, row in df.iterrows()
}
coord_to_name[pool] = "Pool Tanjungsari"
coord_to_name[tpa]  = "TPA Benowo"

for vid in range(n_vehicles):
    # get the raw coordinates in this cluster
    cluster_pts = coords[kmeans.labels_ == vid]
    if len(cluster_pts) == 0:
        continue

    # GA wants a Python list of tuple‐points
    pts_list = [tuple(pt) for pt in cluster_pts]

    # find best ordering of stops
    best_route = ga_cluster(pts_list)

    # build the full trip for plotting
    full_route = [pool] + best_route + [tpa, pool]

    # 1) draw it on the map
    folium.PolyLine(
        locations=full_route,
        color=colors[vid % len(colors)],
        weight=2.5, opacity=0.8,
        popup=f'Vehicle {vid+1}'
    ).add_to(m2)

    # 2) compute the true total distance via route_distance(best_route)
    #    (it already adds pool→stops→TPA→pool)
    total_dist_km = route_distance(best_route) / 1000

    # 3) map coords back to names
    path_names = [coord_to_name[c] for c in full_route]
    print(f"Vehicle {vid+1}: " + " → ".join(path_names))
    print(f"  Total distance: {total_dist_km:.2f} km\n")

# finally show the map
m2

# %%
colors = ['blue', 'purple', 'orange', 'yellow', 'lightred', 'darkblue', 'darkgreen', 'cadetblue', 'darkpurple', 'pink', 'lightblue']

coord_to_name = {
    (row['Latitude'], row['Longitude']): row['LPS/Depo']
    for _, row in df.iterrows()
}
coord_to_name[pool] = "Pool Tanjungsari"
coord_to_name[tpa]  = "TPA Benowo"

for vid in range(n_vehicles):
    # get the raw coordinates in this cluster
    cluster_pts = coords[kmeans.labels_ == vid]
    if len(cluster_pts) == 0:
        continue

    # GA wants a Python list of tuple‐points
    pts_list = [tuple(pt) for pt in cluster_pts]

    # find best ordering of stops
    best_route = ga_cluster(pts_list)

    # build the full trip for plotting
    full_route = [pool] + best_route + [tpa, pool]

    # 1) draw it on the map
    folium.PolyLine(
        locations=full_route,
        color=colors[vid % len(colors)],
        weight=2.5, opacity=0.8,
        popup=f'Vehicle {vid+1}'
    ).add_to(m2)

    # 2) compute the true total distance via route_distance(best_route)
    #    (it already adds pool→stops→TPA→pool)
    total_dist_km = route_distance(best_route) / 1000

    # 3) map coords back to names
    path_names = [coord_to_name[c] for c in full_route]
    print(f"Vehicle {vid+1}: " + " → ".join(path_names))
    print(f"  Total distance: {total_dist_km:.2f} km\n")

# finally show the map
m2
# Out:
# Vehicle 1: Pool Tanjungsari → Sawahan → Pasar Kembang → Kedondong → Pandegiling → Rumah Sakit Darmo / Ketampon → Kaiser → TPA Benowo → Pool Tanjungsari
#   Total distance: 32.22 km
#
# Vehicle 2: Pool Tanjungsari → Alas Malang → Kendung → Babat Jerawat → TPA Benowo → Pool Tanjungsari
#   Total distance: 19.83 km
#
# Vehicle 3: Pool Tanjungsari → Gebang Putih → Keputih → Semolowaru Bahari → TPA Benowo → Pool Tanjungsari
#   Total distance: 46.01 km
#
# Vehicle 4: Pool Tanjungsari → Demak (Kali Butuh) → Kedung Anyar → Pringadi → Pasar Genteng → Makam Peneleh → Sulung Kali → Panghela → Penghela → Dupak → TPA Benowo → Pool Tanjungsari
#   Total distance: 31.67 km
#
# Vehicle 5: Pool Tanjungsari → Jagir → Gayungsari → 3R Jambangan → TPA Benowo → Pool Tanjungsari
#   Total distance: 38.69 km
#
# Vehicle 6: Pool Tanjungsari → Dinoyo → Keputran Selatan → Kayun → Kayon → Srikana → Gubeng → Pacar Keling → Legundi Anggrek → Simpang Dukuh → TPA Benowo → Pool Tanjungsari
#   Total distance: 37.16 km
#
# Vehicle 7: Pool Tanjungsari → Kertopaten → Wonokusumo Kidul → Nyamplungan → TPA Benowo → Pool Tanjungsari
#   Total distance: 33.30 km
#
# Vehicle 8: Pool Tanjungsari → Pesapen → TPA Benowo → Pool Tanjungsari
#   Total distance: 29.32 km
#
# Vehicle 9: Pool Tanjungsari → Pecindilan → Tambak Rejo → Tambak Deres → Simolawang → Pasar Kapasan → TPA Benowo → Pool Tanjungsari
#   Total distance: 39.93 km
#
# Vehicle 10: Pool Tanjungsari → Medokan Ayu → Giyu → TPA Benowo → Pool Tanjungsari
#   Total distance: 46.40 km
#
# Vehicle 11: Pool Tanjungsari → Prada Kali Kendal → TPA Benowo → Pool Tanjungsari
#   Total distance: 21.50 km
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_425a0e1a210063f83f1308b7771d3014 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_425a0e1a210063f83f1308b7771d3014&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_425a0e1a210063f83f1308b7771d3014 = L.map(
#                 &quot;map_425a0e1a210063f83f1308b7771d3014&quot;,
#                 {
#                     center: [-7.26053139, 112.692194],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5616029b3215a7861d2058efec4dd604 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5616029b3215a7861d2058efec4dd604.addTo(map_425a0e1a210063f83f1308b7771d3014);
#
#
#             var marker_07a795ab7d91b3e53efcbdccb77e69d7 = L.marker(
#                 [-7.26053139, 112.692194],
#                 {
# }
#             ).addTo(map_425a0e1a210063f83f1308b7771d3014);
#
#
#             var icon_6d688a3507c7e9a86da1770e01429423 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_11e3cdb4de0a4726828975ed22c8a062 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f542cd99853ad2df9a8c898c32ec02f = $(`&lt;div id=&quot;html_5f542cd99853ad2df9a8c898c32ec02f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pool Tanjungsari&lt;/div&gt;`)[0];
#                 popup_11e3cdb4de0a4726828975ed22c8a062.setContent(html_5f542cd99853ad2df9a8c898c32ec02f);
#
#
#
#         marker_07a795ab7d91b3e53efcbdccb77e69d7.bindPopup(popup_11e3cdb4de0a4726828975ed22c8a062)
#         ;
#
#
#
#
#                 marker_07a795ab7d91b3e53efcbdccb77e69d7.setIcon(icon_6d688a3507c7e9a86da1770e01429423);
#
#
#             var marker_a541b2a378b5dbf9d879ae5c115ae754 = L.marker(
#                 [-7.237391, 112.609436],
#                 {
# }
#             ).addTo(map_425a0e1a210063f83f1308b7771d3014);
#
#
#             var icon_24be19e7b4d8f11defa72564d89c3bcf = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ce1b78224fc0cc3ddf5ed92eb8c3deba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba4281cef177872d38cb18f783d09950 = $(`&lt;div id=&quot;html_ba4281cef177872d38cb18f783d09950&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;TPA Benowo&lt;/div&gt;`)[0];
#                 popup_ce1b78224fc0cc3ddf5ed92eb8c3deba.setContent(html_ba4281cef177872d38cb18f783d09950);
#
#
#
#         marker_a541b2a378b5dbf9d879ae5c115ae754.bindPopup(popup_ce1b78224fc0cc3ddf5ed92eb8c3deba)
#         ;
#
#
#
#
#                 marker_a541b2a378b5dbf9d879ae5c115ae754.setIcon(icon_24be19e7b4d8f11defa72564d89c3bcf);
#
#
#             var poly_line_a21b1bbbade6ef8073cf23479fb1d700 = L.polyline(
#                 [[-7.26053139, 112.692194], [-7.2625942, 112.728107], [-7.269049, 112.729097], [-7.271773, 112.738242], [-7.276231, 112.735806], [-7.287677, 112.736963], [-7.2767204, 112.713377], [-7.237391, 112.609436], [-7.26053139, 112.692194]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_425a0e1a210063f83f1308b7771d3014);
#
#
#         var popup_dca2dbb34d84fe214cbb42a9c14929bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09a5fc847fef72110b70462749b83c1b = $(`&lt;div id=&quot;html_09a5fc847fef72110b70462749b83c1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vehicle 1&lt;/div&gt;`)[0];
#                 popup_dca2dbb34d84fe214cbb42a9c14929bf.setContent(html_09a5fc
